# %%
from modules import *
import tensorflow as tf
from keras.preprocessing.sequence import pad_sequences
import Utils
import Evaluate
import pickle
import os
from tqdm import tqdm
import logging

os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# for train
#embedding_file = "./data/embeddings.pkl"
#train_file = "./data/train.gr.pkl"
#val_file = "./data/dev.gr.pkl"
#evaluate_file = "./data/test.gr.pkl"
embedding_file = "./data/embeddings_ko.pkl"
train_file = "./data/train_ko.pkl"
val_file = "./data/dev_ko.pkl"
evaluate_file = "./data/test_ko.pkl"

save_path = "./model/cpre/"
result_path = "./output/cpre/"
log_path = "./model/cpre/"

max_sentence_len = 50
max_num_utterance = 11
batch_size = 50
eval_batch_size = 100

# %%
class ScriptWriter_cpre():
    def __init__(self, eta=0.5):
        self.max_num_utterance = max_num_utterance
        self.negative_samples = 1
        self.max_sentence_len = max_sentence_len
        self.word_embedding_size = 200
        self.hidden_units = 200
        #self.total_words = 43514
        self.total_words = 11883
        self.batch_size = batch_size
        self.eval_batch_size = eval_batch_size
        self.learning_rate_ph = tf.compat.v1.placeholder(tf.float32, shape=[], name='learning_rate')
        self.dropout_rate = 0
        self.num_heads = 1
        self.num_blocks = 3
        self.eta = eta
        self.gamma = tf.compat.v1.get_variable('gamma', shape=1, dtype=tf.float32, trainable=True, initializer=tf.constant_initializer(0.5))

        self.embedding_ph = tf.compat.v1.placeholder(tf.float32, shape=(self.total_words, self.word_embedding_size))
        self.utterance_ph = tf.compat.v1.placeholder(tf.int32, shape=(None, max_num_utterance, max_sentence_len))
        self.response_ph = tf.compat.v1.placeholder(tf.int32, shape=(None, max_sentence_len))
        self.gt_response_ph = tf.compat.v1.placeholder(tf.int32, shape=(None, max_sentence_len))
        self.y_true_ph = tf.compat.v1.placeholder(tf.int32, shape=(None,))
        self.narrative_ph = tf.compat.v1.placeholder(tf.int32, shape=(None, max_sentence_len))

        self.word_embeddings = tf.compat.v1.get_variable('word_embeddings_v', shape=(self.total_words, self.word_embedding_size), dtype=tf.float32, trainable=False)
        self.embedding_init = self.word_embeddings.assign(self.embedding_ph)
        self.global_step = tf.Variable(0, name='global_step', trainable=False)
        self.is_training = True
        print("current eta: ", self.eta)

    def load(self, previous_modelpath):
        #sess = tf.Session()
        sess = tf.compat.v1.Session()
        latest_ckpt = tf.compat.v1.train.latest_checkpoint(previous_modelpath)
        # print("recover from checkpoint: " + latest_ckpt)
        #variables = tf.contrib.framework.get_variables_to_restore()
        #variables = tf.compat.v1.get_variables_to_restore()
        #saver = tf.train.Saver(variables)
        saver = tf.compat.v1.train.Saver()
        saver.restore(sess, latest_ckpt)
        return sess

    def build(self):
        print('utterance_ph.shape =', self.utterance_ph.shape)
        all_utterances = tf.unstack(self.utterance_ph, num=self.max_num_utterance, axis=1)
        print('len(all_utterances) =', len(all_utterances))
        print('len(all_utterances[0].shape =', all_utterances[0].shape)
        reuse = None
        alpha_1, alpha_2 = None, None

        print('response_ph.shape =', self.response_ph.shape)
        response_embeddings = embedding(self.response_ph, initializer=self.word_embeddings)
        print('response_embeddings.shape =', response_embeddings.shape)
        Hr_stack = [response_embeddings]
        for i in range(self.num_blocks):
            with tf.compat.v1.variable_scope("num_blocks_{}".format(i)):
                response_embeddings, _ = multihead_attention(queries=response_embeddings, keys=response_embeddings, num_units=self.hidden_units, num_heads=self.num_heads, is_training=self.is_training, causality=False, dropout_rate=self.dropout_rate)
                print(i, 'response_embeddings.shape =', response_embeddings.shape)
                response_embeddings = feedforward(response_embeddings, num_units=[self.hidden_units, self.hidden_units])
                print(i, 'response_embeddings.shape =', response_embeddings.shape)
                Hr_stack.append(response_embeddings)
        #print('-----------------------------------------')
        #for v in tf.compat.v1.global_variables():
        #    print(v.name)
        #print('-----------------------------------------')

        gt_response_embeddings = embedding(self.gt_response_ph, initializer=self.word_embeddings)
        print('gt_response_embeddings.shape =', gt_response_embeddings.shape)
        Hgtr_stack = [gt_response_embeddings]
        for i in range(self.num_blocks):
            with tf.compat.v1.variable_scope("num_blocks_{}".format(i), reuse=True):
                gt_response_embeddings, _ = multihead_attention(queries=gt_response_embeddings, keys=gt_response_embeddings, num_units=self.hidden_units, num_heads=self.num_heads, is_training=self.is_training, causality=False, dropout_rate=self.dropout_rate)
                gt_response_embeddings = feedforward(gt_response_embeddings, num_units=[self.hidden_units, self.hidden_units])
                Hgtr_stack.append(gt_response_embeddings)
        #print('-----------------------------------------')
        #for v in tf.compat.v1.global_variables():
        #    print(v.name)
        #print('-----------------------------------------')

        narrative_embeddings = embedding(self.narrative_ph, initializer=self.word_embeddings)
        print('narrative_embeddings.shape =', narrative_embeddings.shape)
        Hn_stack = [narrative_embeddings]
        for i in range(self.num_blocks):
            with tf.compat.v1.variable_scope("num_blocks_{}".format(i), reuse=True):
                narrative_embeddings, _ = multihead_attention(queries=narrative_embeddings, keys=narrative_embeddings, num_units=self.hidden_units, num_heads=self.num_heads, is_training=self.is_training, causality=False, dropout_rate=self.dropout_rate)
                narrative_embeddings = feedforward(narrative_embeddings, num_units=[self.hidden_units, self.hidden_units])
                Hn_stack.append(narrative_embeddings)

        Mur, Mun = [], []
        self.decay_factor = []
        last_u_reps = []
        turn_id = 0
        for utterance in all_utterances:
            utterance_embeddings = embedding(utterance, initializer=self.word_embeddings)
            print('utterance_embeddings.shape =', utterance_embeddings.shape)
            Hu_stack = [utterance_embeddings]
            for i in range(self.num_blocks):
                with tf.compat.v1.variable_scope("num_blocks_{}".format(i), reuse=True):
                    utterance_embeddings, _ = multihead_attention(queries=utterance_embeddings, keys=utterance_embeddings, num_units=self.hidden_units, num_heads=self.num_heads, is_training=self.is_training, causality=False, dropout_rate=self.dropout_rate)
                    utterance_embeddings = feedforward(utterance_embeddings, num_units=[self.hidden_units, self.hidden_units])
                    Hu_stack.append(utterance_embeddings)

            if turn_id == self.max_num_utterance - 1:
                last_u_reps = Hu_stack

            # response_attention_uttrance
            r_a_u_stack = []
            # utterance_attention_response
            u_a_r_stack = []

            for i in range(self.num_blocks + 1):
                with tf.compat.v1.variable_scope("utterance_attention_response_{}".format(i), reuse=reuse):
                    u_a_r, _ = multihead_attention(queries=Hu_stack[i], keys=Hr_stack[i], num_units=self.hidden_units, num_heads=self.num_heads, is_training=self.is_training, causality=False, dropout_rate=self.dropout_rate)
                    u_a_r = feedforward(u_a_r, num_units=[self.hidden_units, self.hidden_units])
                    u_a_r_stack.append(u_a_r)
                with tf.compat.v1.variable_scope("response_attention_utterance_{}".format(i), reuse=reuse):
                    r_a_u, _ = multihead_attention(queries=Hr_stack[i], keys=Hu_stack[i], num_units=self.hidden_units, num_heads=self.num_heads, is_training=self.is_training, causality=False, dropout_rate=self.dropout_rate)
                    r_a_u = feedforward(r_a_u, num_units=[self.hidden_units, self.hidden_units])
                    r_a_u_stack.append(r_a_u)
                    
            # concat u_a_r + Hu
            u_a_r_stack.extend(Hu_stack)
            # concat r_a_u + Hr
            r_a_u_stack.extend(Hr_stack)

            n_a_u_stack = []
            u_a_n_stack = []
            for i in range(self.num_blocks + 1):
                with tf.compat.v1.variable_scope("narrative_attention_response_{}".format(i), reuse=reuse):
                    n_a_u, _ = multihead_attention(queries=Hn_stack[i], keys=Hu_stack[i], num_units=self.hidden_units, num_heads=self.num_heads, is_training=self.is_training, causality=False, dropout_rate=self.dropout_rate)
                    n_a_u = feedforward(n_a_u, num_units=[self.hidden_units, self.hidden_units])
                    n_a_u_stack.append(n_a_u)
                with tf.compat.v1.variable_scope("response_attention_narrative_{}".format(i), reuse=reuse):
                    u_a_n, alpha_1 = multihead_attention(queries=Hu_stack[i], keys=Hn_stack[i], num_units=self.hidden_units, num_heads=self.num_heads, is_training=self.is_training, causality=False, dropout_rate=self.dropout_rate)
                    u_a_n = feedforward(u_a_n, num_units=[self.hidden_units, self.hidden_units])
                    u_a_n_stack.append(u_a_n)
            n_a_u_stack.extend(Hn_stack)
            u_a_n_stack.extend(Hu_stack)

            u_a_r = tf.stack(u_a_r_stack, axis=-1)
            r_a_u = tf.stack(r_a_u_stack, axis=-1)
            u_a_n = tf.stack(u_a_n_stack, axis=-1)
            n_a_u = tf.stack(n_a_u_stack, axis=-1)
            
            print('final u_a_r.shape =', u_a_r.shape)

            # similarity matrix 계산
            with tf.compat.v1.variable_scope('similarity'):
                # sim shape [batch, max_sent_len, max_sent_len, 2 * (stack_num + 1)]
                # divide sqrt(200) to prevent gradient explosion
                # no rp의 의미는?
                sim_ur = tf.einsum('biks,bjks->bijs', u_a_r, r_a_u) / tf.sqrt(200.0)  # for no rp and normal
                sim_un = tf.einsum('biks,bjks->bijs', u_a_n, n_a_u) / tf.sqrt(200.0)  # for no rp and normal
            print('sim_ur.shape =', sim_ur.shape)

            self_n = tf.nn.l2_normalize(tf.stack(Hn_stack, axis=-1))  # #for no rp
            self_u = tf.nn.l2_normalize(tf.stack(Hu_stack, axis=-1))  # #for no rp
            Hn_stack_tensor = tf.stack(Hn_stack, axis=-1)  # [batch, o_len, embedding_size, stack]
            print('Hn_stack_tensor.shape =', Hn_stack_tensor.shape)
            with tf.compat.v1.variable_scope('similarity'):
                self_sim = tf.einsum('biks,bjks->bijs', self_u, self_n)  # [batch, u_len, o_len, stack]
                self_sim = 1 - self.gamma * tf.reduce_sum(self_sim, axis=1)  # [batch, (1), o_len, stack]
                Hn_stack = tf.einsum('bjkl,bjl->bjkl', Hn_stack_tensor, self_sim)
                Hn_stack = tf.unstack(Hn_stack, axis=-1, num=self.num_blocks + 1)

            Mur.append(sim_ur)
            Mun.append(sim_un)
            turn_id += 1
            if not reuse:
                reuse = True
        
        print('narrative updated final len(Hn_stack) =', len(Hn_stack), ', Hn_stack[0].shape =', Hn_stack[0].shape)

        print('stack shape = ', tf.stack(Hn_stack, axis=2).shape)
        Hn_stack_for_tracking = tf.compat.v1.layers.dense(tf.stack(Hn_stack, axis=2), self.hidden_units)  # [batch, o_len, stack, embedding_size]
        print('Hn_stack_for_tracking.shape after dense =', Hn_stack_for_tracking.shape)
        Hn_stack_for_tracking = tf.transpose(Hn_stack_for_tracking, perm=[0, 1, 3, 2])  # [batch, o_len, embedding_size, stack]
        Hlastu_stack_for_tracking = tf.stack(last_u_reps, axis=-1)  # [batch, u_len, embedding_size, stack]
        Hr_stack_for_tracking = tf.stack(Hgtr_stack, axis=-1)  # [batch, r_len, embedding_size, stack]
        Hlastu = tf.transpose(Hlastu_stack_for_tracking, perm=[0, 2, 3, 1])
        Hlastu = tf.squeeze(tf.compat.v1.layers.dense(Hlastu, 1), axis=-1)  # [batch, embedding_size, stack]
        p1_tensor = tf.nn.softmax(tf.einsum('bnds,bds->bns', Hn_stack_for_tracking, Hlastu), axis=1)  # [batch, o_len, stack]
        Hlastur = tf.transpose(Hr_stack_for_tracking, perm=[0, 2, 3, 1])
        Hlastur = tf.squeeze(tf.compat.v1.layers.dense(Hlastur, 1), axis=-1)  # [batch, embedding_size, stack]
        p2_tensor = tf.nn.softmax(tf.einsum('bnds,bds->bns', Hn_stack_for_tracking, Hlastur), axis=1)  # [batch, o_len, stack]
        p1 = tf.unstack(p1_tensor, num=self.num_blocks + 1, axis=-1)
        p2 = tf.unstack(p2_tensor, num=self.num_blocks + 1, axis=-1)

        r_a_n_stack = []
        n_a_r_stack = []
        for i in range(self.num_blocks + 1):
            with tf.compat.v1.variable_scope("narrative_attention_response_{}".format(i), reuse=True):
                n_a_r, _ = multihead_attention(queries=Hn_stack[i], keys=Hr_stack[i], num_units=self.hidden_units, num_heads=self.num_heads, is_training=self.is_training, causality=False, dropout_rate=self.dropout_rate)
                n_a_r = feedforward(n_a_r, num_units=[self.hidden_units, self.hidden_units])
                n_a_r_stack.append(n_a_r)
            with tf.compat.v1.variable_scope("response_attention_narrative_{}".format(i), reuse=True):
                r_a_n, _ = multihead_attention(queries=Hr_stack[i], keys=Hn_stack[i], num_units=self.hidden_units, num_heads=self.num_heads, is_training=self.is_training, causality=False, dropout_rate=self.dropout_rate)
                r_a_n = feedforward(r_a_n, num_units=[self.hidden_units, self.hidden_units])
                r_a_n_stack.append(r_a_n)

        n_a_r_stack.extend(Hn_stack)
        r_a_n_stack.extend(Hr_stack)
        n_a_r = tf.stack(n_a_r_stack, axis=-1)
        r_a_n = tf.stack(r_a_n_stack, axis=-1)

        with tf.compat.v1.variable_scope('similarity'):
            Mrn = tf.einsum('biks,bjks->bijs', n_a_r, r_a_n) / tf.sqrt(200.0)
        self.rosim = Mrn
        Mur = tf.stack(Mur, axis=1)
        Mun = tf.stack(Mun, axis=1) 
        print('Mur.shape =', Mur.shape)
        print('Mun.shape =', Mun.shape)
        with tf.compat.v1.variable_scope('cnn_aggregation'):
            conv3d = tf.compat.v1.layers.conv3d(Mur, filters=32, kernel_size=[3, 3, 3], padding="SAME", activation=tf.nn.elu, kernel_initializer=tf.random_uniform_initializer(-0.01, 0.01), name="conv1")
            pool3d = tf.compat.v1.layers.max_pooling3d(conv3d, pool_size=[3, 3, 3], strides=[3, 3, 3], padding="SAME")
            conv3d2 = tf.compat.v1.layers.conv3d(pool3d, filters=32, kernel_size=[3, 3, 3], padding="SAME", activation=tf.nn.elu, kernel_initializer=tf.random_uniform_initializer(-0.01, 0.01), name="conv2")
            pool3d2 = tf.compat.v1.layers.max_pooling3d(conv3d2, pool_size=[3, 3, 3], strides=[3, 3, 3], padding="SAME")
            mur = tf.compat.v1.layers.flatten(pool3d2)
            print('mur conv3d =', conv3d)
            print('mur conv3d2 =', conv3d2)
        with tf.compat.v1.variable_scope('cnn_aggregation', reuse=True):
            conv3d = tf.compat.v1.layers.conv3d(Mun, filters=32, kernel_size=[3, 3, 3], padding="SAME", activation=tf.nn.elu, kernel_initializer=tf.random_uniform_initializer(-0.01, 0.01), name="conv1")
            pool3d = tf.compat.v1.layers.max_pooling3d(conv3d, pool_size=[3, 3, 3], strides=[3, 3, 3], padding="SAME")
            conv3d2 = tf.compat.v1.layers.conv3d(pool3d, filters=32, kernel_size=[3, 3, 3], padding="SAME", activation=tf.nn.elu, kernel_initializer=tf.random_uniform_initializer(-0.01, 0.01), name="conv2")
            pool3d2 = tf.compat.v1.layers.max_pooling3d(conv3d2, pool_size=[3, 3, 3], strides=[3, 3, 3], padding="SAME")
            mun = tf.compat.v1.layers.flatten(pool3d2)
            print('mun conv3d =', conv3d)
            print('mun conv3d2 =', conv3d2)
        with tf.compat.v1.variable_scope('cnn_aggregation'):
            conv2d = tf.compat.v1.layers.conv2d(Mrn, filters=32, kernel_size=[3, 3], padding="SAME", activation=tf.nn.elu, kernel_initializer=tf.random_uniform_initializer(-0.01, 0.01), name="conv2d")
            pool2d = tf.compat.v1.layers.max_pooling2d(conv2d, pool_size=[3, 3], strides=[3, 3], padding="SAME")
            conv2d2 = tf.compat.v1.layers.conv2d(pool2d, filters=32, kernel_size=[3, 3], padding="SAME", activation=tf.nn.elu, kernel_initializer=tf.random_uniform_initializer(-0.01, 0.01), name="conv2d2")
            pool2d2 = tf.compat.v1.layers.max_pooling2d(conv2d2, pool_size=[3, 3], strides=[3, 3], padding="SAME")
            print('mrn conv2d =', conv2d)
            print('mrn conv2d2 =', conv2d2)
            mrn = tf.compat.v1.layers.flatten(pool2d2)

        all_vector = tf.concat([mur, mun, mrn], axis=-1)
        logits = tf.reshape(tf.compat.v1.layers.dense(all_vector, 1, kernel_initializer=tf.compat.v1.orthogonal_initializer()), [-1])

        self.y_pred = tf.sigmoid(logits)
        """
        KL_loss = 0.0
        for i in range(self.num_blocks + 1):
            KL_loss += tf.reduce_mean(tf.keras.losses.kullback_leibler_divergence(p1[i], p2[i]))
        KL_loss /= (self.num_blocks + 1)
        
        optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=self.learning_rate_ph, beta1=0.9, beta2=0.98, epsilon=1e-8)
        RS_loss = tf.reduce_mean(tf.clip_by_value(tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.cast(self.y_true_ph, tf.float32), logits=logits), -10, 10))
        self.loss = self.eta * RS_loss + (1 - self.eta) * KL_loss
        self.all_variables = tf.compat.v1.global_variables()
        self.grads_and_vars = optimizer.compute_gradients(self.loss)

        for grad, var in self.grads_and_vars:
            if grad is None:
                print(var)

        self.capped_gvs = [(tf.clip_by_value(grad, -5, 5), var) for grad, var in self.grads_and_vars]
        self.train_op = optimizer.apply_gradients(self.capped_gvs, global_step=self.global_step)
        self.saver = tf.compat.v1.train.Saver(max_to_keep=10)
        self.alpha_1 = alpha_1
        """
        # self.alpha_2 = alpha_2
        # self.train_op = self.optimizer.minimize(self.loss, global_step=self.global_step)

# %%
config = tf.compat.v1.ConfigProto(allow_soft_placement=True)
config.gpu_options.allow_growth = True
with tf.compat.v1.Session(config=config) as sess:
    eta = 0.7
    model = ScriptWriter_cpre(eta)
    model.build()
    
    # The session is binding to the default global graph
    tf.compat.v1.profiler.profile(
        sess.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation())
    parameters = tf.compat.v1.profiler.profile(sess.graph,
                                     options=tf.compat.v1.profiler.ProfileOptionBuilder
                                     .trainable_variables_parameter())
    print ('total parameters: {}'.format(parameters.total_parameters))
# Out:
# 2022-09-22 14:47:08.669608: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-22 14:47:09.227995: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 17608 MB memory:  -> device: 0, name: GeForce RTX 3090, pci bus id: 0000:65:00.0, compute capability: 8.6
# /home/kotech/venv-cpre/lib/python3.9/site-packages/keras/legacy_tf_layers/core.py:236: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /home/kotech/venv-cpre/lib/python3.9/site-packages/keras/engine/base_layer_v1.py:1676: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# /home/kotech/venv-cpre/lib/python3.9/site-packages/keras/legacy_tf_layers/core.py:393: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   warnings.warn('`tf.layers.dropout` is deprecated and '
# /home/kotech/venv-cpre/lib/python3.9/site-packages/keras/legacy_tf_layers/convolutional.py:263: UserWarning: `tf.layers.conv1d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv1D` instead.
#   warnings.warn('`tf.layers.conv1d` is deprecated and '
# current eta:  0.7
# utterance_ph.shape = (None, 11, 50)
# len(all_utterances) = 11
# len(all_utterances[0].shape = (None, 50)
# response_ph.shape = (None, 50)
# response_embeddings.shape = (None, 50, 200)
# 0 response_embeddings.shape = (None, 50, 200)
# 0 response_embeddings.shape = (None, 50, 200)
# 1 response_embeddings.shape = (None, 50, 200)
# 1 response_embeddings.shape = (None, 50, 200)
# 2 response_embeddings.shape = (None, 50, 200)
# 2 response_embeddings.shape = (None, 50, 200)
# gt_response_embeddings.shape = (None, 50, 200)
# narrative_embeddings.shape = (None, 50, 200)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# sim_ur.shape = (None, 50, 50, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# sim_ur.shape = (None, 50, 50, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# sim_ur.shape = (None, 50, 50, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# sim_ur.shape = (None, 50, 50, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# sim_ur.shape = (None, 50, 50, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# sim_ur.shape = (None, 50, 50, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# sim_ur.shape = (None, 50, 50, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# sim_ur.shape = (None, 50, 50, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# sim_ur.shape = (None, 50, 50, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# sim_ur.shape = (None, 50, 50, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# sim_ur.shape = (None, 50, 50, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# narrative updated final len(Hn_stack) = 4 , Hn_stack[0].shape = (None, 50, 200)
# stack shape =  (None, 50, 4, 200)
# Hn_stack_for_tracking.shape after dense = (None, 50, 4, 200)
# Mur.shape = (None, 11, 50, 50, 8)
# Mun.shape = (None, 11, 50, 50, 8)
# mur conv3d = Tensor("cnn_aggregation/conv1/Elu:0", shape=(None, 11, 50, 50, 32), dtype=float32)
# mur conv3d2 = Tensor("cnn_aggregation/conv2/Elu:0", shape=(None, 4, 17, 17, 32), dtype=float32)
# mun conv3d = Tensor("cnn_aggregation_1/conv1/Elu:0", shape=(None, 11, 50, 50, 32), dtype=float32)
# mun conv3d2 = Tensor("cnn_aggregation_1/conv2/Elu:0", shape=(None, 4, 17, 17, 32), dtype=float32)
# mrn conv2d = Tensor("cnn_aggregation_2/conv2d/Elu:0", shape=(None, 50, 50, 32), dtype=float32)
# mrn conv2d2 = Tensor("cnn_aggregation_2/conv2d2/Elu:0", shape=(None, 17, 17, 32), dtype=float32)
# WARNING:tensorflow:From /home/kotech/venv-cpre/lib/python3.9/site-packages/tensorflow/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# /home/kotech/venv-cpre/lib/python3.9/site-packages/keras/legacy_tf_layers/convolutional.py:811: UserWarning: `tf.layers.conv3d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv3D` instead.
#   warnings.warn('`tf.layers.conv3d` is deprecated and '
# /home/kotech/venv-cpre/lib/python3.9/site-packages/keras/legacy_tf_layers/pooling.py:830: UserWarning: `tf.layers.max_pooling3d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.MaxPooling3D` instead.
#   warnings.warn('`tf.layers.max_pooling3d` is deprecated and '
# /home/kotech/venv-cpre/lib/python3.9/site-packages/keras/legacy_tf_layers/core.py:513: UserWarning: `tf.layers.flatten` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Flatten` instead.
#   warnings.warn('`tf.layers.flatten` is deprecated and '
# /home/kotech/venv-cpre/lib/python3.9/site-packages/keras/legacy_tf_layers/convolutional.py:536: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   warnings.warn('`tf.layers.conv2d` is deprecated and '
# /home/kotech/venv-cpre/lib/python3.9/site-packages/keras/legacy_tf_layers/pooling.py:554: UserWarning: `tf.layers.max_pooling2d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.MaxPooling2D` instead.
#   warnings.warn('`tf.layers.max_pooling2d` is deprecated and '
# 7604 ops no flops stats due to incomplete shapes.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/6.28m flops)
#   word_embeddings_v/Initializer/random_uniform/mul (2.38m/2.38m flops)
#   response_attention_utterance_0/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_2/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_2/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_3/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_2/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_1/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_2/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_3/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_2/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_0/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_3/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_3/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_3/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_1/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_3/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_3/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_3/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_3/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_1/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_1/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_1/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_0/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_1/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_0/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_1/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_0/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_1/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_1/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_0/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_0/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_0/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_0/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_0/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_2/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_1/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_0/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_1/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_2/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_2/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_1/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_2/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_1/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_2/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_0/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_2/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_1/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_2/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_0/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_1/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_0/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_3/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_1/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_1/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_2/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_1/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_0/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_0/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_2/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_0/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_1/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_0/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_2/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_0/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_1/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   num_blocks_0/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_0/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_3/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_1/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_0/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_2/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_2/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_2/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_2/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_2/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_2/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_0/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_2/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   narrative_attention_response_0/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_3/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_3/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_3/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_3/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_3/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_3/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_3/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_3/multihead_attention/dense_2/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_3/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_2/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_2/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_1/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_1/feed_forward/conv1d_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_utterance_0/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_1/feed_forward/conv1d/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   utterance_attention_response_1/multihead_attention/dense_1/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   response_attention_narrative_2/multihead_attention/dense/kernel/Initializer/random_uniform/mul (40.00k/40.00k flops)
#   cnn_aggregation/conv2/kernel/Initializer/random_uniform/mul (27.65k/27.65k flops)
#   cnn_aggregation/conv2d2/kernel/Initializer/random_uniform/mul (9.22k/9.22k flops)
#   cnn_aggregation/conv1/kernel/Initializer/random_uniform/mul (6.91k/6.91k flops)
#   dense_3/kernel/Initializer/mul (5.76k/5.76k flops)
#   dense_3/kernel/Initializer/mul_1 (5.76k/5.76k flops)
#   dense_3/kernel/Initializer/random_normal/mul (5.76k/5.76k flops)
#   cnn_aggregation/conv2d/kernel/Initializer/random_uniform/mul (2.30k/2.30k flops)
#   dense_1/kernel/Initializer/random_uniform/mul (50/50 flops)
#   dense_2/kernel/Initializer/random_uniform/mul (50/50 flops)
#   l2_normalize_1/Rsqrt (2/2 flops)
#   l2_normalize_20/Rsqrt (2/2 flops)
#   l2_normalize_6/Rsqrt (2/2 flops)
#   l2_normalize/Rsqrt (2/2 flops)
#   l2_normalize_7/Rsqrt (2/2 flops)
#   l2_normalize_8/Rsqrt (2/2 flops)
#   l2_normalize_9/Rsqrt (2/2 flops)
#   l2_normalize_15/Rsqrt (2/2 flops)
#   l2_normalize_2/Rsqrt (2/2 flops)
#   l2_normalize_19/Rsqrt (2/2 flops)
#   l2_normalize_18/Rsqrt (2/2 flops)
#   l2_normalize_21/Rsqrt (2/2 flops)
#   l2_normalize_17/Rsqrt (2/2 flops)
#   l2_normalize_16/Rsqrt (2/2 flops)
#   l2_normalize_10/Rsqrt (2/2 flops)
#   l2_normalize_3/Rsqrt (2/2 flops)
#   l2_normalize_14/Rsqrt (2/2 flops)
#   l2_normalize_13/Rsqrt (2/2 flops)
#   l2_normalize_4/Rsqrt (2/2 flops)
#   l2_normalize_12/Rsqrt (2/2 flops)
#   l2_normalize_11/Rsqrt (2/2 flops)
#   l2_normalize_5/Rsqrt (2/2 flops)
#   response_attention_utterance_0/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_0/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_0/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_1/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_3/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_0/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_0/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_3/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_1/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_3/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_2/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_1/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_1/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_1/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_1/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_1/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_2/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_2/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_2/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_0/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_2/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_3/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_3/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_3/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_3/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_3/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   word_embeddings_v/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_3/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_1/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_1/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_2/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_2/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_2/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_2/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_2/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_3/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_1/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_3/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_utterance_3/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_2/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_0/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_0/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_0/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   utterance_attention_response_0/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   l2_normalize_9/Maximum (1/1 flops)
#   l2_normalize_19/Maximum (1/1 flops)
#   l2_normalize_2/Maximum (1/1 flops)
#   l2_normalize_20/Maximum (1/1 flops)
#   l2_normalize_21/Maximum (1/1 flops)
#   l2_normalize_3/Maximum (1/1 flops)
#   l2_normalize_4/Maximum (1/1 flops)
#   l2_normalize_5/Maximum (1/1 flops)
#   l2_normalize_6/Maximum (1/1 flops)
#   l2_normalize_7/Maximum (1/1 flops)
#   l2_normalize_8/Maximum (1/1 flops)
#   l2_normalize_18/Maximum (1/1 flops)
#   narrative_attention_response_0/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_0/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_0/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_0/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_0/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_1/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_1/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_1/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_1/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_1/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   l2_normalize/Maximum (1/1 flops)
#   Sub_1 (1/1 flops)
#   Sub_2 (1/1 flops)
#   Sub_3 (1/1 flops)
#   cnn_aggregation/conv1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   cnn_aggregation/conv2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   cnn_aggregation/conv2d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   cnn_aggregation/conv2d2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_2/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   l2_normalize_1/Maximum (1/1 flops)
#   l2_normalize_10/Maximum (1/1 flops)
#   l2_normalize_11/Maximum (1/1 flops)
#   l2_normalize_12/Maximum (1/1 flops)
#   l2_normalize_13/Maximum (1/1 flops)
#   l2_normalize_14/Maximum (1/1 flops)
#   l2_normalize_15/Maximum (1/1 flops)
#   l2_normalize_16/Maximum (1/1 flops)
#   l2_normalize_17/Maximum (1/1 flops)
#   response_attention_narrative_1/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_2/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_2/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_2/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_0/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_0/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_0/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_0/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_0/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_1/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_1/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   Sub (1/1 flops)
#   response_attention_narrative_1/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_1/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_2/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_2/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_2/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_2/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_2/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_3/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_3/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_0/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_2/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_2/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_2/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_2/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_3/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_3/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_3/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_3/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   narrative_attention_response_3/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_0/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   response_attention_narrative_3/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_0/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_0/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_0/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_1/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_1/feed_forward/conv1d_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_1/multihead_attention/dense/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_1/multihead_attention/dense_1/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_1/multihead_attention/dense_2/kernel/Initializer/random_uniform/sub (1/1 flops)
#   num_blocks_2/feed_forward/conv1d/kernel/Initializer/random_uniform/sub (1/1 flops)
#
# ======================End of Report==========================
# 7604 ops no flops stats due to incomplete shapes.
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoototal parameters: 3926472
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# Incomplete shape.
# t (--/3.93m params)
#   cnn_aggregation (--/46.21k params)
#     cnn_aggregation/conv1 (--/6.94k params)
#       cnn_aggregation/conv1/bias (32, 32/32 params)
#       cnn_aggregation/conv1/kernel (3x3x3x8x32, 6.91k/6.91k params)
#     cnn_aggregation/conv2 (--/27.68k params)
#       cnn_aggregation/conv2/bias (32, 32/32 params)
#       cnn_aggregation/conv2/kernel (3x3x3x32x32, 27.65k/27.65k params)
#     cnn_aggregation/conv2d (--/2.34k params)
#       cnn_aggregation/conv2d/bias (32, 32/32 params)
#       cnn_aggregation/conv2d/kernel (3x3x8x32, 2.30k/2.30k params)
#     cnn_aggregation/conv2d2 (--/9.25k params)
#       cnn_aggregation/conv2d2/bias (32, 32/32 params)
#       cnn_aggregation/conv2d2/kernel (3x3x32x32, 9.22k/9.22k params)
#   dense (--/40.20k params)
#     dense/bias (200, 200/200 params)
#     dense/kernel (200x200, 40.00k/40.00k params)
#   dense_1 (--/51 params)
#     dense_1/bias (1, 1/1 params)
#     dense_1/kernel (50x1, 50/50 params)
#   dense_2 (--/51 params)
#     dense_2/bias (1, 1/1 params)
#     dense_2/kernel (50x1, 50/50 params)
#   dense_3 (--/5.76k params)
#     dense_3/bias (1, 1/1 params)
#     dense_3/kernel (5760x1, 5.76k/5.76k params)
#   gamma (1, 1/1 params)
#   narrative_attention_response_0 (--/201.80k params)
#     narrative_attention_response_0/feed_forward (--/80.80k params)
#       narrative_attention_response_0/feed_forward/conv1d (--/40.20k params)
#         narrative_attention_response_0/feed_forward/conv1d/bias (200, 200/200 params)
#         narrative_attention_response_0/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       narrative_attention_response_0/feed_forward/conv1d_1 (--/40.20k params)
#         narrative_attention_response_0/feed_forward/conv1d_1/bias (200, 200/200 params)
#         narrative_attention_response_0/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       narrative_attention_response_0/feed_forward/feed_forward (--/400 params)
#         narrative_attention_response_0/feed_forward/feed_forward/beta (200, 200/200 params)
#         narrative_attention_response_0/feed_forward/feed_forward/scale (200, 200/200 params)
#     narrative_attention_response_0/multihead_attention (--/121.00k params)
#       narrative_attention_response_0/multihead_attention/dense (--/40.20k params)
#         narrative_attention_response_0/multihead_attention/dense/bias (200, 200/200 params)
#         narrative_attention_response_0/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_0/multihead_attention/dense_1 (--/40.20k params)
#         narrative_attention_response_0/multihead_attention/dense_1/bias (200, 200/200 params)
#         narrative_attention_response_0/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_0/multihead_attention/dense_2 (--/40.20k params)
#         narrative_attention_response_0/multihead_attention/dense_2/bias (200, 200/200 params)
#         narrative_attention_response_0/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_0/multihead_attention/multihead_attention (--/400 params)
#         narrative_attention_response_0/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         narrative_attention_response_0/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   narrative_attention_response_1 (--/201.80k params)
#     narrative_attention_response_1/feed_forward (--/80.80k params)
#       narrative_attention_response_1/feed_forward/conv1d (--/40.20k params)
#         narrative_attention_response_1/feed_forward/conv1d/bias (200, 200/200 params)
#         narrative_attention_response_1/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       narrative_attention_response_1/feed_forward/conv1d_1 (--/40.20k params)
#         narrative_attention_response_1/feed_forward/conv1d_1/bias (200, 200/200 params)
#         narrative_attention_response_1/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       narrative_attention_response_1/feed_forward/feed_forward (--/400 params)
#         narrative_attention_response_1/feed_forward/feed_forward/beta (200, 200/200 params)
#         narrative_attention_response_1/feed_forward/feed_forward/scale (200, 200/200 params)
#     narrative_attention_response_1/multihead_attention (--/121.00k params)
#       narrative_attention_response_1/multihead_attention/dense (--/40.20k params)
#         narrative_attention_response_1/multihead_attention/dense/bias (200, 200/200 params)
#         narrative_attention_response_1/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_1/multihead_attention/dense_1 (--/40.20k params)
#         narrative_attention_response_1/multihead_attention/dense_1/bias (200, 200/200 params)
#         narrative_attention_response_1/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_1/multihead_attention/dense_2 (--/40.20k params)
#         narrative_attention_response_1/multihead_attention/dense_2/bias (200, 200/200 params)
#         narrative_attention_response_1/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_1/multihead_attention/multihead_attention (--/400 params)
#         narrative_attention_response_1/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         narrative_attention_response_1/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   narrative_attention_response_2 (--/201.80k params)
#     narrative_attention_response_2/feed_forward (--/80.80k params)
#       narrative_attention_response_2/feed_forward/conv1d (--/40.20k params)
#         narrative_attention_response_2/feed_forward/conv1d/bias (200, 200/200 params)
#         narrative_attention_response_2/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       narrative_attention_response_2/feed_forward/conv1d_1 (--/40.20k params)
#         narrative_attention_response_2/feed_forward/conv1d_1/bias (200, 200/200 params)
#         narrative_attention_response_2/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       narrative_attention_response_2/feed_forward/feed_forward (--/400 params)
#         narrative_attention_response_2/feed_forward/feed_forward/beta (200, 200/200 params)
#         narrative_attention_response_2/feed_forward/feed_forward/scale (200, 200/200 params)
#     narrative_attention_response_2/multihead_attention (--/121.00k params)
#       narrative_attention_response_2/multihead_attention/dense (--/40.20k params)
#         narrative_attention_response_2/multihead_attention/dense/bias (200, 200/200 params)
#         narrative_attention_response_2/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_2/multihead_attention/dense_1 (--/40.20k params)
#         narrative_attention_response_2/multihead_attention/dense_1/bias (200, 200/200 params)
#         narrative_attention_response_2/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_2/multihead_attention/dense_2 (--/40.20k params)
#         narrative_attention_response_2/multihead_attention/dense_2/bias (200, 200/200 params)
#         narrative_attention_response_2/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_2/multihead_attention/multihead_attention (--/400 params)
#         narrative_attention_response_2/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         narrative_attention_response_2/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   narrative_attention_response_3 (--/201.80k params)
#     narrative_attention_response_3/feed_forward (--/80.80k params)
#       narrative_attention_response_3/feed_forward/conv1d (--/40.20k params)
#         narrative_attention_response_3/feed_forward/conv1d/bias (200, 200/200 params)
#         narrative_attention_response_3/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       narrative_attention_response_3/feed_forward/conv1d_1 (--/40.20k params)
#         narrative_attention_response_3/feed_forward/conv1d_1/bias (200, 200/200 params)
#         narrative_attention_response_3/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       narrative_attention_response_3/feed_forward/feed_forward (--/400 params)
#         narrative_attention_response_3/feed_forward/feed_forward/beta (200, 200/200 params)
#         narrative_attention_response_3/feed_forward/feed_forward/scale (200, 200/200 params)
#     narrative_attention_response_3/multihead_attention (--/121.00k params)
#       narrative_attention_response_3/multihead_attention/dense (--/40.20k params)
#         narrative_attention_response_3/multihead_attention/dense/bias (200, 200/200 params)
#         narrative_attention_response_3/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_3/multihead_attention/dense_1 (--/40.20k params)
#         narrative_attention_response_3/multihead_attention/dense_1/bias (200, 200/200 params)
#         narrative_attention_response_3/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_3/multihead_attention/dense_2 (--/40.20k params)
#         narrative_attention_response_3/multihead_attention/dense_2/bias (200, 200/200 params)
#         narrative_attention_response_3/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       narrative_attention_response_3/multihead_attention/multihead_attention (--/400 params)
#         narrative_attention_response_3/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         narrative_attention_response_3/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   num_blocks_0 (--/201.80k params)
#     num_blocks_0/feed_forward (--/80.80k params)
#       num_blocks_0/feed_forward/conv1d (--/40.20k params)
#         num_blocks_0/feed_forward/conv1d/bias (200, 200/200 params)
#         num_blocks_0/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       num_blocks_0/feed_forward/conv1d_1 (--/40.20k params)
#         num_blocks_0/feed_forward/conv1d_1/bias (200, 200/200 params)
#         num_blocks_0/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       num_blocks_0/feed_forward/feed_forward (--/400 params)
#         num_blocks_0/feed_forward/feed_forward/beta (200, 200/200 params)
#         num_blocks_0/feed_forward/feed_forward/scale (200, 200/200 params)
#     num_blocks_0/multihead_attention (--/121.00k params)
#       num_blocks_0/multihead_attention/dense (--/40.20k params)
#         num_blocks_0/multihead_attention/dense/bias (200, 200/200 params)
#         num_blocks_0/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       num_blocks_0/multihead_attention/dense_1 (--/40.20k params)
#         num_blocks_0/multihead_attention/dense_1/bias (200, 200/200 params)
#         num_blocks_0/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       num_blocks_0/multihead_attention/dense_2 (--/40.20k params)
#         num_blocks_0/multihead_attention/dense_2/bias (200, 200/200 params)
#         num_blocks_0/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       num_blocks_0/multihead_attention/multihead_attention (--/400 params)
#         num_blocks_0/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         num_blocks_0/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   num_blocks_1 (--/201.80k params)
#     num_blocks_1/feed_forward (--/80.80k params)
#       num_blocks_1/feed_forward/conv1d (--/40.20k params)
#         num_blocks_1/feed_forward/conv1d/bias (200, 200/200 params)
#         num_blocks_1/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       num_blocks_1/feed_forward/conv1d_1 (--/40.20k params)
#         num_blocks_1/feed_forward/conv1d_1/bias (200, 200/200 params)
#         num_blocks_1/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       num_blocks_1/feed_forward/feed_forward (--/400 params)
#         num_blocks_1/feed_forward/feed_forward/beta (200, 200/200 params)
#         num_blocks_1/feed_forward/feed_forward/scale (200, 200/200 params)
#     num_blocks_1/multihead_attention (--/121.00k params)
#       num_blocks_1/multihead_attention/dense (--/40.20k params)
#         num_blocks_1/multihead_attention/dense/bias (200, 200/200 params)
#         num_blocks_1/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       num_blocks_1/multihead_attention/dense_1 (--/40.20k params)
#         num_blocks_1/multihead_attention/dense_1/bias (200, 200/200 params)
#         num_blocks_1/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       num_blocks_1/multihead_attention/dense_2 (--/40.20k params)
#         num_blocks_1/multihead_attention/dense_2/bias (200, 200/200 params)
#         num_blocks_1/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       num_blocks_1/multihead_attention/multihead_attention (--/400 params)
#         num_blocks_1/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         num_blocks_1/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   num_blocks_2 (--/201.80k params)
#     num_blocks_2/feed_forward (--/80.80k params)
#       num_blocks_2/feed_forward/conv1d (--/40.20k params)
#         num_blocks_2/feed_forward/conv1d/bias (200, 200/200 params)
#         num_blocks_2/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       num_blocks_2/feed_forward/conv1d_1 (--/40.20k params)
#         num_blocks_2/feed_forward/conv1d_1/bias (200, 200/200 params)
#         num_blocks_2/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       num_blocks_2/feed_forward/feed_forward (--/400 params)
#         num_blocks_2/feed_forward/feed_forward/beta (200, 200/200 params)
#         num_blocks_2/feed_forward/feed_forward/scale (200, 200/200 params)
#     num_blocks_2/multihead_attention (--/121.00k params)
#       num_blocks_2/multihead_attention/dense (--/40.20k params)
#         num_blocks_2/multihead_attention/dense/bias (200, 200/200 params)
#         num_blocks_2/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       num_blocks_2/multihead_attention/dense_1 (--/40.20k params)
#         num_blocks_2/multihead_attention/dense_1/bias (200, 200/200 params)
#         num_blocks_2/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       num_blocks_2/multihead_attention/dense_2 (--/40.20k params)
#         num_blocks_2/multihead_attention/dense_2/bias (200, 200/200 params)
#         num_blocks_2/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       num_blocks_2/multihead_attention/multihead_attention (--/400 params)
#         num_blocks_2/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         num_blocks_2/multihead_attention/multihead_attention/scale (200, 200/200 params)
# ...
#       response_attention_utterance_0/multihead_attention/dense_1 (--/40.20k params)
#         response_attention_utterance_0/multihead_attention/dense_1/bias (200, 200/200 params)
#         response_attention_utterance_0/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       response_attention_utterance_0/multihead_attention/dense_2 (--/40.20k params)
#         response_attention_utterance_0/multihead_attention/dense_2/bias (200, 200/200 params)
#         response_attention_utterance_0/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       response_attention_utterance_0/multihead_attention/multihead_attention (--/400 params)
#         response_attention_utterance_0/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         response_attention_utterance_0/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   response_attention_utterance_1 (--/201.80k params)
#     response_attention_utterance_1/feed_forward (--/80.80k params)
#       response_attention_utterance_1/feed_forward/conv1d (--/40.20k params)
#         response_attention_utterance_1/feed_forward/conv1d/bias (200, 200/200 params)
#         response_attention_utterance_1/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       response_attention_utterance_1/feed_forward/conv1d_1 (--/40.20k params)
#         response_attention_utterance_1/feed_forward/conv1d_1/bias (200, 200/200 params)
#         response_attention_utterance_1/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       response_attention_utterance_1/feed_forward/feed_forward (--/400 params)
#         response_attention_utterance_1/feed_forward/feed_forward/beta (200, 200/200 params)
#         response_attention_utterance_1/feed_forward/feed_forward/scale (200, 200/200 params)
#     response_attention_utterance_1/multihead_attention (--/121.00k params)
#       response_attention_utterance_1/multihead_attention/dense (--/40.20k params)
#         response_attention_utterance_1/multihead_attention/dense/bias (200, 200/200 params)
#         response_attention_utterance_1/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       response_attention_utterance_1/multihead_attention/dense_1 (--/40.20k params)
#         response_attention_utterance_1/multihead_attention/dense_1/bias (200, 200/200 params)
#         response_attention_utterance_1/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       response_attention_utterance_1/multihead_attention/dense_2 (--/40.20k params)
#         response_attention_utterance_1/multihead_attention/dense_2/bias (200, 200/200 params)
#         response_attention_utterance_1/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       response_attention_utterance_1/multihead_attention/multihead_attention (--/400 params)
#         response_attention_utterance_1/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         response_attention_utterance_1/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   response_attention_utterance_2 (--/201.80k params)
#     response_attention_utterance_2/feed_forward (--/80.80k params)
#       response_attention_utterance_2/feed_forward/conv1d (--/40.20k params)
#         response_attention_utterance_2/feed_forward/conv1d/bias (200, 200/200 params)
#         response_attention_utterance_2/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       response_attention_utterance_2/feed_forward/conv1d_1 (--/40.20k params)
#         response_attention_utterance_2/feed_forward/conv1d_1/bias (200, 200/200 params)
#         response_attention_utterance_2/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       response_attention_utterance_2/feed_forward/feed_forward (--/400 params)
#         response_attention_utterance_2/feed_forward/feed_forward/beta (200, 200/200 params)
#         response_attention_utterance_2/feed_forward/feed_forward/scale (200, 200/200 params)
#     response_attention_utterance_2/multihead_attention (--/121.00k params)
#       response_attention_utterance_2/multihead_attention/dense (--/40.20k params)
#         response_attention_utterance_2/multihead_attention/dense/bias (200, 200/200 params)
#         response_attention_utterance_2/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       response_attention_utterance_2/multihead_attention/dense_1 (--/40.20k params)
#         response_attention_utterance_2/multihead_attention/dense_1/bias (200, 200/200 params)
#         response_attention_utterance_2/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       response_attention_utterance_2/multihead_attention/dense_2 (--/40.20k params)
#         response_attention_utterance_2/multihead_attention/dense_2/bias (200, 200/200 params)
#         response_attention_utterance_2/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       response_attention_utterance_2/multihead_attention/multihead_attention (--/400 params)
#         response_attention_utterance_2/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         response_attention_utterance_2/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   response_attention_utterance_3 (--/201.80k params)
#     response_attention_utterance_3/feed_forward (--/80.80k params)
#       response_attention_utterance_3/feed_forward/conv1d (--/40.20k params)
#         response_attention_utterance_3/feed_forward/conv1d/bias (200, 200/200 params)
#         response_attention_utterance_3/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       response_attention_utterance_3/feed_forward/conv1d_1 (--/40.20k params)
#         response_attention_utterance_3/feed_forward/conv1d_1/bias (200, 200/200 params)
#         response_attention_utterance_3/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       response_attention_utterance_3/feed_forward/feed_forward (--/400 params)
#         response_attention_utterance_3/feed_forward/feed_forward/beta (200, 200/200 params)
#         response_attention_utterance_3/feed_forward/feed_forward/scale (200, 200/200 params)
#     response_attention_utterance_3/multihead_attention (--/121.00k params)
#       response_attention_utterance_3/multihead_attention/dense (--/40.20k params)
#         response_attention_utterance_3/multihead_attention/dense/bias (200, 200/200 params)
#         response_attention_utterance_3/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       response_attention_utterance_3/multihead_attention/dense_1 (--/40.20k params)
#         response_attention_utterance_3/multihead_attention/dense_1/bias (200, 200/200 params)
#         response_attention_utterance_3/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       response_attention_utterance_3/multihead_attention/dense_2 (--/40.20k params)
#         response_attention_utterance_3/multihead_attention/dense_2/bias (200, 200/200 params)
#         response_attention_utterance_3/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       response_attention_utterance_3/multihead_attention/multihead_attention (--/400 params)
#         response_attention_utterance_3/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         response_attention_utterance_3/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   utterance_attention_response_0 (--/201.80k params)
#     utterance_attention_response_0/feed_forward (--/80.80k params)
#       utterance_attention_response_0/feed_forward/conv1d (--/40.20k params)
#         utterance_attention_response_0/feed_forward/conv1d/bias (200, 200/200 params)
#         utterance_attention_response_0/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       utterance_attention_response_0/feed_forward/conv1d_1 (--/40.20k params)
#         utterance_attention_response_0/feed_forward/conv1d_1/bias (200, 200/200 params)
#         utterance_attention_response_0/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       utterance_attention_response_0/feed_forward/feed_forward (--/400 params)
#         utterance_attention_response_0/feed_forward/feed_forward/beta (200, 200/200 params)
#         utterance_attention_response_0/feed_forward/feed_forward/scale (200, 200/200 params)
#     utterance_attention_response_0/multihead_attention (--/121.00k params)
#       utterance_attention_response_0/multihead_attention/dense (--/40.20k params)
#         utterance_attention_response_0/multihead_attention/dense/bias (200, 200/200 params)
#         utterance_attention_response_0/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_0/multihead_attention/dense_1 (--/40.20k params)
#         utterance_attention_response_0/multihead_attention/dense_1/bias (200, 200/200 params)
#         utterance_attention_response_0/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_0/multihead_attention/dense_2 (--/40.20k params)
#         utterance_attention_response_0/multihead_attention/dense_2/bias (200, 200/200 params)
#         utterance_attention_response_0/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_0/multihead_attention/multihead_attention (--/400 params)
#         utterance_attention_response_0/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         utterance_attention_response_0/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   utterance_attention_response_1 (--/201.80k params)
#     utterance_attention_response_1/feed_forward (--/80.80k params)
#       utterance_attention_response_1/feed_forward/conv1d (--/40.20k params)
#         utterance_attention_response_1/feed_forward/conv1d/bias (200, 200/200 params)
#         utterance_attention_response_1/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       utterance_attention_response_1/feed_forward/conv1d_1 (--/40.20k params)
#         utterance_attention_response_1/feed_forward/conv1d_1/bias (200, 200/200 params)
#         utterance_attention_response_1/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       utterance_attention_response_1/feed_forward/feed_forward (--/400 params)
#         utterance_attention_response_1/feed_forward/feed_forward/beta (200, 200/200 params)
#         utterance_attention_response_1/feed_forward/feed_forward/scale (200, 200/200 params)
#     utterance_attention_response_1/multihead_attention (--/121.00k params)
#       utterance_attention_response_1/multihead_attention/dense (--/40.20k params)
#         utterance_attention_response_1/multihead_attention/dense/bias (200, 200/200 params)
#         utterance_attention_response_1/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_1/multihead_attention/dense_1 (--/40.20k params)
#         utterance_attention_response_1/multihead_attention/dense_1/bias (200, 200/200 params)
#         utterance_attention_response_1/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_1/multihead_attention/dense_2 (--/40.20k params)
#         utterance_attention_response_1/multihead_attention/dense_2/bias (200, 200/200 params)
#         utterance_attention_response_1/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_1/multihead_attention/multihead_attention (--/400 params)
#         utterance_attention_response_1/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         utterance_attention_response_1/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   utterance_attention_response_2 (--/201.80k params)
#     utterance_attention_response_2/feed_forward (--/80.80k params)
#       utterance_attention_response_2/feed_forward/conv1d (--/40.20k params)
#         utterance_attention_response_2/feed_forward/conv1d/bias (200, 200/200 params)
#         utterance_attention_response_2/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       utterance_attention_response_2/feed_forward/conv1d_1 (--/40.20k params)
#         utterance_attention_response_2/feed_forward/conv1d_1/bias (200, 200/200 params)
#         utterance_attention_response_2/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       utterance_attention_response_2/feed_forward/feed_forward (--/400 params)
#         utterance_attention_response_2/feed_forward/feed_forward/beta (200, 200/200 params)
#         utterance_attention_response_2/feed_forward/feed_forward/scale (200, 200/200 params)
#     utterance_attention_response_2/multihead_attention (--/121.00k params)
#       utterance_attention_response_2/multihead_attention/dense (--/40.20k params)
#         utterance_attention_response_2/multihead_attention/dense/bias (200, 200/200 params)
#         utterance_attention_response_2/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_2/multihead_attention/dense_1 (--/40.20k params)
#         utterance_attention_response_2/multihead_attention/dense_1/bias (200, 200/200 params)
#         utterance_attention_response_2/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_2/multihead_attention/dense_2 (--/40.20k params)
#         utterance_attention_response_2/multihead_attention/dense_2/bias (200, 200/200 params)
#         utterance_attention_response_2/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_2/multihead_attention/multihead_attention (--/400 params)
#         utterance_attention_response_2/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         utterance_attention_response_2/multihead_attention/multihead_attention/scale (200, 200/200 params)
#   utterance_attention_response_3 (--/201.80k params)
#     utterance_attention_response_3/feed_forward (--/80.80k params)
#       utterance_attention_response_3/feed_forward/conv1d (--/40.20k params)
#         utterance_attention_response_3/feed_forward/conv1d/bias (200, 200/200 params)
#         utterance_attention_response_3/feed_forward/conv1d/kernel (1x200x200, 40.00k/40.00k params)
#       utterance_attention_response_3/feed_forward/conv1d_1 (--/40.20k params)
#         utterance_attention_response_3/feed_forward/conv1d_1/bias (200, 200/200 params)
#         utterance_attention_response_3/feed_forward/conv1d_1/kernel (1x200x200, 40.00k/40.00k params)
#       utterance_attention_response_3/feed_forward/feed_forward (--/400 params)
#         utterance_attention_response_3/feed_forward/feed_forward/beta (200, 200/200 params)
#         utterance_attention_response_3/feed_forward/feed_forward/scale (200, 200/200 params)
#     utterance_attention_response_3/multihead_attention (--/121.00k params)
#       utterance_attention_response_3/multihead_attention/dense (--/40.20k params)
#         utterance_attention_response_3/multihead_attention/dense/bias (200, 200/200 params)
#         utterance_attention_response_3/multihead_attention/dense/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_3/multihead_attention/dense_1 (--/40.20k params)
#         utterance_attention_response_3/multihead_attention/dense_1/bias (200, 200/200 params)
#         utterance_attention_response_3/multihead_attention/dense_1/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_3/multihead_attention/dense_2 (--/40.20k params)
#         utterance_attention_response_3/multihead_attention/dense_2/bias (200, 200/200 params)
#         utterance_attention_response_3/multihead_attention/dense_2/kernel (200x200, 40.00k/40.00k params)
#       utterance_attention_response_3/multihead_attention/multihead_attention (--/400 params)
#         utterance_attention_response_3/multihead_attention/multihead_attention/beta (200, 200/200 params)
#         utterance_attention_response_3/multihead_attention/multihead_attention/scale (200, 200/200 params)
#
# ======================End of Report==========================

# %%
np.random.seed(42)
n_word = 3
n_embedded = 200
n_layer = 4
a = np.random.rand(n_word,n_embedded, n_layer)
b = np.random.rand(n_word,n_embedded, n_layer)
a = tf.constant(a)
b = tf.constant(b)

print(a.shape)
# no axis to normalize
a_norm = tf.nn.l2_normalize(a)
b_norm = tf.nn.l2_normalize(b)
sim = tf.einsum('iks,jks->ijs', a_norm, b_norm)
print(sim.shape)
# error => not a cos value
print(sim)

# correct axis
a_norm = tf.nn.l2_normalize(a, axis=-2)
b_norm = tf.nn.l2_normalize(b, axis=-2)
sim = tf.einsum('iks,jks->ijs', a_norm, b_norm)
print(sim)
# Out:
# (3, 200, 4)
# (3, 3, 4)
# tf.Tensor(
# [[[0.06010767 0.06378155 0.05901452 0.06585608]
#   [0.06380126 0.06155514 0.05672619 0.06431459]
#   [0.05930824 0.06996205 0.05641049 0.06446883]]
#
#  [[0.06605667 0.06170718 0.06172836 0.06438432]
#   [0.06272271 0.05952186 0.0580241  0.0619105 ]
#   [0.06559977 0.06484434 0.06050366 0.0632573 ]]
#
#  [[0.06482191 0.06460671 0.0640206  0.06081453]
#   [0.06481846 0.06164986 0.06160087 0.06007434]
#   [0.06385889 0.06763946 0.05821728 0.05710631]]], shape=(3, 3, 4), dtype=float64)
# tf.Tensor(
# [[[0.7240082  0.74178509 0.74320613 0.74550174]
#   [0.77379084 0.7383667  0.71035131 0.75591322]
#   [0.73729438 0.78331064 0.73551692 0.76322202]]
#
#  [[0.74706631 0.73788542 0.7534658  0.76420142]
#   [0.71424635 0.73409873 0.70424917 0.76295987]
#   [0.76569717 0.74647238 0.76461505 0.7852115 ]]
#
#  [[0.75946848 0.76109677 0.78030435 0.72576216]
#   [0.76465834 0.74906433 0.74656952 0.7443645 ]
#   [0.77218547 0.76709798 0.73464672 0.71272073]]], shape=(3, 3, 4), dtype=float64)

# %%
a = tf.constant([1.1,1.1])
a_norm = tf.nn.l2_normalize(a, axis=-1)
print(a_norm.numpy())
a = tf.constant([[1.0, 1.0], [1.0, 1.0]])
a_norm = tf.nn.l2_normalize(a)
print(a_norm.numpy())
a = tf.constant([[1.1, 1.1], [1.1, 1.1], [2.0, 1.0]])
a_norm = tf.nn.l2_normalize(a, axis=-1)
print(a_norm.numpy())
a = tf.constant([[1.1, 1.1], [1.1, 1.1], [2.0, 1.0]])
a_norm = tf.nn.l2_normalize(a)
print(a_norm.numpy())
a = tf.constant([[[1.0, 1.0], [2.0, 2.0]], [[2.0, 1.0], [4.0, 2.0]]])
print(a.shape)
a_norm = tf.nn.l2_normalize(a, axis=-1)
print(a_norm.numpy())
# Out:
# [0.7071068 0.7071068]
# [[0.5 0.5]
#  [0.5 0.5]]
# [[0.7071068  0.7071068 ]
#  [0.7071068  0.7071068 ]
#  [0.8944271  0.44721356]]
# [[0.35066718 0.35066718]
#  [0.35066718 0.35066718]
#  [0.6375767  0.31878835]]
# (2, 2, 2)
# [[[0.7071067  0.7071067 ]
#   [0.7071067  0.7071067 ]]
#
#  [[0.8944271  0.44721356]
#   [0.8944271  0.44721356]]]

# %%
x = tf.constant([[1., 1.], [2., 2.]])
print(tf.reduce_mean(x).numpy())
x = tf.constant([[1., 1.], [2., 2.]])
print(tf.reduce_mean(x, axis=0).numpy())
x = tf.constant([[1., 1.], [2., 2.]])
print(tf.reduce_mean(x, axis=1).numpy())
x = tf.constant([[1., 1.], [2., 2.]])
print(tf.reduce_mean(x, axis=(0,1)).numpy())
# Out:
# 1.5
# [1.5 1.5]
# [1. 2.]
# 1.5

# %%
# KL divergence
np.random.seed(42)
n_batch = 2
n_word = 3
n_embedded = 200
n_layer = 4
q = np.random.rand(n_batch, n_word, n_layer)
p = np.random.rand(n_batch, n_word, n_layer)
q = tf.constant(q)
p = tf.constant(p)
q_tensor = tf.nn.softmax(q, axis=1)
p_tensor = tf.nn.softmax(p, axis=1)
print(q_tensor)
q = tf.unstack(q_tensor, n_layer, axis=-1)
p = tf.unstack(p_tensor, n_layer, axis=-1)
print(q)
KL_loss = 0.0
for i in range(n_layer):
    KL_loss += tf.reduce_mean(tf.keras.losses.kullback_leibler_divergence(p[i], q[i]))
    print(tf.keras.losses.kullback_leibler_divergence(p[i], q[i]))
KL_loss /= (n_layer)
# Out:
# tf.Tensor(
# [[[0.32701082 0.44717513 0.49983424 0.26622196]
#   [0.26282063 0.20199249 0.25477128 0.34787669]
#   [0.41016855 0.35083238 0.24539449 0.38590135]]
#
#  [[0.41811075 0.30335483 0.2940472  0.30169411]
#   [0.24654535 0.41460262 0.37760941 0.33604271]
#   [0.33534391 0.28204255 0.32834339 0.36226318]]], shape=(2, 3, 4), dtype=float64)
# [<tf.Tensor: shape=(2, 3), dtype=float64, numpy=
# array([[0.32701082, 0.26282063, 0.41016855],
#        [0.41811075, 0.24654535, 0.33534391]])>, <tf.Tensor: shape=(2, 3), dtype=float64, numpy=
# array([[0.44717513, 0.20199249, 0.35083238],
#        [0.30335483, 0.41460262, 0.28204255]])>, <tf.Tensor: shape=(2, 3), dtype=float64, numpy=
# array([[0.49983424, 0.25477128, 0.24539449],
#        [0.2940472 , 0.37760941, 0.32834339]])>, <tf.Tensor: shape=(2, 3), dtype=float64, numpy=
# array([[0.26622196, 0.34787669, 0.38590135],
#        [0.30169411, 0.33604271, 0.36226318]])>]
# tf.Tensor([0.07625552 0.00970438], shape=(2,), dtype=float64)
# tf.Tensor([0.01844393 0.04050933], shape=(2,), dtype=float64)
# tf.Tensor([0.18779343 0.06754503], shape=(2,), dtype=float64)
# tf.Tensor([0.03194485 0.02150445], shape=(2,), dtype=float64)
# tf.Tensor(0.05671261569948419, shape=(), dtype=float64)

# %%
# reuse=True 테스트
# 이 코드는 재 실행은 되지 않음. (restart 필요)
import tensorflow as tf

with tf.compat.v1.Session() as sess:
    
    inputs_1 = tf.compat.v1.placeholder(tf.float32, (None, 512, 512, 3), name='inputs_1')
    inputs_2 = tf.compat.v1.placeholder(tf.float32, (None, 512, 512, 3), name='inputs_2')

    with tf.compat.v1.variable_scope('conv'):
        out_1 = tf.compat.v1.layers.conv2d(inputs_1, 32, [3, 3], name='conv_1')

    with tf.compat.v1.variable_scope('conv', reuse=True):
        out_2 = tf.compat.v1.layers.conv2d(inputs_2, 32, [3, 3], name='conv_1')

    init = tf.compat.v1.global_variables_initializer()

    sess.run(init)
    print(tf.compat.v1.trainable_variables())
# Out:
# 2022-08-23 10:29:37.487947: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [<tf.Variable 'conv/conv_1/kernel:0' shape=(3, 3, 3, 32) dtype=float32>, <tf.Variable 'conv/conv_1/bias:0' shape=(32,) dtype=float32>]
# 2022-08-23 10:29:38.304030: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-08-23 10:29:38.304091: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1303 MB memory:  -> device: 0, name: GeForce RTX 3090, pci bus id: 0000:65:00.0, compute capability: 8.6
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/convolutional.py:536: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   warnings.warn('`tf.layers.conv2d` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/engine/base_layer_v1.py:1676: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
log_path = "./model/cpre/all_log"
logging.basicConfig(filename=log_path, level=logging.INFO)
logger = logging.getLogger(__name__)
eta = 0.7
save_path = "./model/cpre/"
result_path = "./output/cpre/"
if not os.path.exists(save_path):
    os.mkdir(save_path)
if not os.path.exists(result_path):
    os.mkdir(result_path)
logger.info("Current Eta: %.2f" % eta)
train(eta=eta, logger=logger)
# Out:
# 2022-08-12 16:44:52.974466: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-12 16:44:53.520605: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21469 MB memory:  -> device: 0, name: GeForce RTX 3090, pci bus id: 0000:65:00.0, compute capability: 8.6
# WARNING:tensorflow:From /tmp/ipykernel_16256/3534897697.py:15: DatasetV1.make_initializable_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# This is a deprecated API that should only be used in TF 1 graph mode and legacy TF 2 graph mode available through `tf.compat.v1`. In all other situations -- namely, eager mode and inside `tf.function` -- you can consume dataset elements using `for elem in dataset: ...` or by explicitly creating iterator via `iterator = iter(dataset)` and fetching its elements via `values = next(iterator)`. Furthermore, this API is not available in TF 2. During the transition from TF 1 to TF 2 you can use `tf.compat.v1.data.make_initializable_iterator(dataset)` to create a TF 1 graph mode style iterator for a dataset created through TF 2 APIs. Note that this should be a transient state of your code base as there are in general no guarantees about the interoperability of TF 1 and TF 2 code.
# current eta:  0.7
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/core.py:236: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/engine/base_layer_v1.py:1676: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/core.py:393: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   warnings.warn('`tf.layers.dropout` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/convolutional.py:263: UserWarning: `tf.layers.conv1d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv1D` instead.
#   warnings.warn('`tf.layers.conv1d` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/convolutional.py:811: UserWarning: `tf.layers.conv3d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv3D` instead.
#   warnings.warn('`tf.layers.conv3d` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/pooling.py:830: UserWarning: `tf.layers.max_pooling3d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.MaxPooling3D` instead.
#   warnings.warn('`tf.layers.max_pooling3d` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/core.py:513: UserWarning: `tf.layers.flatten` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Flatten` instead.
#   warnings.warn('`tf.layers.flatten` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/convolutional.py:536: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   warnings.warn('`tf.layers.conv2d` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/pooling.py:554: UserWarning: `tf.layers.max_pooling2d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.MaxPooling2D` instead.
#   warnings.warn('`tf.layers.max_pooling2d` is deprecated and '
# Epoch  1 / 4
#   0%|                                                                    | 0/246578 [00:00<?, ?it/s]2022-08-12 16:47:54.177301: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-08-12 16:47:54.648735: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8200
#  10%|██▏                   | 25000/246578 [13:59<2:04:02, 29.77it/s, learning_rate=0.001, loss=0.27]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_16256/250485085.py in <module>
#      11     os.mkdir(result_path)
#      12 logger.info("Current Eta: %.2f" % eta)
# ---> 13 train(eta=eta, logger=logger)
#
# /tmp/ipykernel_16256/3534897697.py in train(eta, load, model_path, logger)
#      74                                 pass
#      75                             all_candidate_scores = np.concatenate(all_candidate_scores, axis=0)
# ---> 76                             result = Evaluate.evaluate_all(all_candidate_scores, y_true_val)
#      77                             if result[0] + result[1] + result[2] + result[3] + result[4] > best_result[0] + best_result[1] + best_result[2] + best_result[3] + best_result[4]:
#      78                                 best_result = result
#
# ~/workspace/ScriptWriter/Evaluate.py in evaluate_all(scores, labels)
#      33 def evaluate_all(scores, labels):
#      34     return compute_acc(scores, labels), compute_r_n_m(scores, labels, 2, 1), compute_r_n_m(scores, labels, 10, 1), compute_r_n_m(scores, labels, 10, 2), \
# ---> 35            compute_r_n_m(scores, labels, 10, 5), compute_mrr(scores, labels)
#      36
#      37 def evaluate_all_from_file(path):
#
# ~/workspace/ScriptWriter/Evaluate.py in compute_r_n_m(scores, labels, count, at)
#      10             pos_score = sublist[0]
#      11             sublist = sorted(sublist, key=lambda x: x, reverse=True)
# ---> 12             if sublist[at - 1] <= pos_score:
#      13                 correct += 1
#      14     return float(correct) / total
#
# IndexError: list index out of range

# %%
def evaluate(model_path, eval_file, output_path, eta):
    with open(eval_file, 'rb') as f:
        utterance, response, narrative, gt_response, y_true = pickle.load(f)

    config = tf.compat.v1.ConfigProto(allow_soft_placement=True)
    config.gpu_options.allow_growth = True
        
    current_lr = 1e-3
    all_candidate_scores = []
    
    with tf.compat.v1.Session(config=config) as sess:
        dataset = tf.compat.v1.data.Dataset.from_tensor_slices((utterance, narrative, response, gt_response, y_true)).batch(eval_batch_size)
        iterator = dataset.make_initializable_iterator()
        data_iterator = iterator.get_next()

        with open(embedding_file, 'rb') as f:
            embeddings = pickle.load(f)

        model = ScriptWriter_cpre(eta)
        model.build()
        sess = model.load(model_path)
        sess.run(iterator.initializer)
        sess.run(model.embedding_init, feed_dict={model.embedding_ph: embeddings})

        test_loss = 0.0
        step = 0
        try:
            with tqdm(total=len(y_true), ncols=100) as pbar:
                while True:
                    bu, bn, br, bgtr, by = data_iterator
                    bu, bn, br, bgtr, by = sess.run([bu, bn, br, bgtr, by])
                    candidate_scores, loss = sess.run([model.y_pred, model.loss], feed_dict={
                        model.utterance_ph: bu, 
                        model.narrative_ph: bn,
                        model.response_ph: br,
                        model.gt_response_ph: bgtr,
                        model.y_true_ph: by,
                        model.learning_rate_ph: current_lr
                    })
                    all_candidate_scores.append(candidate_scores)
                    test_loss += loss
                    pbar.update(model.eval_batch_size)
                    step += 1
        except tf.errors.OutOfRangeError:
            pass

        #sess.close()
    tf.compat.v1.reset_default_graph()

    all_candidate_scores = np.concatenate(all_candidate_scores, axis=0)
    with open(output_path + "test.result.micro_session.txt", "w") as fw:
        for sc in all_candidate_scores.tolist():
            fw.write(str(sc) + "\n")
    return Evaluate.evaluate_all(all_candidate_scores, y_true), test_loss / step, all_candidate_scores.tolist()

# %%
(acc, r2_1, r10_1, r10_2, r10_5, mrr), eva_loss, _ = evaluate(save_path, evaluate_file, output_path=result_path, eta=eta)
print("Loss on test set: %f, R2@1: %f, R10@1: %f, R10@2: %f, R10@5: %f, MRR: %f" % (eva_loss, r2_1, r10_1, r10_2, r10_5, mrr))
# Out:
# 2022-08-08 17:35:07.917683: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21469 MB memory:  -> device: 0, name: GeForce RTX 3090, pci bus id: 0000:65:00.0, compute capability: 8.6
# current eta:  0.7
# 2022-08-08 17:36:05.857107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21469 MB memory:  -> device: 0, name: GeForce RTX 3090, pci bus id: 0000:65:00.0, compute capability: 8.6
# INFO:tensorflow:Restoring parameters from ./model/cpre/model
# 38400it [02:09, 297.55it/s]
# Loss on test set: 0.458008, R2@1: 0.736691, R10@1: 0.376566, R10@2: 0.539144, R10@5: 0.817067, MRR: 0.494602

# %%
with open(evaluate_file, 'rb') as f:
    utterance, response, narrative, gt_response, y_true = pickle.load(f)
    
config = tf.compat.v1.ConfigProto(allow_soft_placement=True)
config.gpu_options.allow_growth = True
        
current_lr = 1e-3
all_candidate_scores = []

eta = 0.7

# %%
with tf.compat.v1.Session(config=config) as sess:
    dataset = tf.compat.v1.data.Dataset.from_tensor_slices((utterance, narrative, response, gt_response, y_true)).batch(eval_batch_size)
    iterator = dataset.make_initializable_iterator()
    data_iterator = iterator.get_next()

    with open(embedding_file, 'rb') as f:
        embeddings = pickle.load(f)

    model = ScriptWriter_cpre(eta)
    model.build()
    sess.run(tf.compat.v1.global_variables_initializer())
    sess.run(iterator.initializer)
    sess.run(model.embedding_init, feed_dict={model.embedding_ph: embeddings})
    test_loss = 0.0
    step = 0
    bu, bn, br, bgtr, by = data_iterator
    bu, bn, br, bgtr, by = sess.run([bu, bn, br, bgtr, by])
    candidate_scores, loss = sess.run([model.y_pred, model.loss], feed_dict={
        model.utterance_ph: bu, 
        model.narrative_ph: bn,
        model.response_ph: br,
        model.gt_response_ph: bgtr,
        model.y_true_ph: by,
        model.learning_rate_ph: current_lr
    })
    all_candidate_scores.append(candidate_scores)
    test_loss += loss
    step += 1
# Out:
# 2022-08-23 17:46:39.106173: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-23 17:46:40.021151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1377 MB memory:  -> device: 0, name: GeForce RTX 3090, pci bus id: 0000:65:00.0, compute capability: 8.6
# WARNING:tensorflow:From /tmp/ipykernel_32009/2798287037.py:3: DatasetV1.make_initializable_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# This is a deprecated API that should only be used in TF 1 graph mode and legacy TF 2 graph mode available through `tf.compat.v1`. In all other situations -- namely, eager mode and inside `tf.function` -- you can consume dataset elements using `for elem in dataset: ...` or by explicitly creating iterator via `iterator = iter(dataset)` and fetching its elements via `values = next(iterator)`. Furthermore, this API is not available in TF 2. During the transition from TF 1 to TF 2 you can use `tf.compat.v1.data.make_initializable_iterator(dataset)` to create a TF 1 graph mode style iterator for a dataset created through TF 2 APIs. Note that this should be a transient state of your code base as there are in general no guarantees about the interoperability of TF 1 and TF 2 code.
# current eta:  0.7
# utterance_ph.shape = (None, 11, 50)
# len(all_utterances) = 11
# len(all_utterances[0].shape = (None, 50)
# response_ph.shape = (None, 50)
# response_embeddings.shape = (None, 50, 200)
# 0 response_embeddings.shape = (None, 50, 200)
# 0 response_embeddings.shape = (None, 50, 200)
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/core.py:236: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/engine/base_layer_v1.py:1676: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/core.py:393: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   warnings.warn('`tf.layers.dropout` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/convolutional.py:263: UserWarning: `tf.layers.conv1d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv1D` instead.
#   warnings.warn('`tf.layers.conv1d` is deprecated and '
# 1 response_embeddings.shape = (None, 50, 200)
# 1 response_embeddings.shape = (None, 50, 200)
# 2 response_embeddings.shape = (None, 50, 200)
# 2 response_embeddings.shape = (None, 50, 200)
# gt_response_embeddings.shape = (None, 50, 200)
# narrative_embeddings.shape = (None, 50, 200)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# utterance_embeddings.shape = (None, 50, 200)
# final u_a_r.shape = (None, 50, 200, 8)
# Hn_stack_tensor.shape = (None, 50, 200, 4)
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/convolutional.py:811: UserWarning: `tf.layers.conv3d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv3D` instead.
#   warnings.warn('`tf.layers.conv3d` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/pooling.py:830: UserWarning: `tf.layers.max_pooling3d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.MaxPooling3D` instead.
#   warnings.warn('`tf.layers.max_pooling3d` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/core.py:513: UserWarning: `tf.layers.flatten` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Flatten` instead.
#   warnings.warn('`tf.layers.flatten` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/convolutional.py:536: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   warnings.warn('`tf.layers.conv2d` is deprecated and '
# /home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/pooling.py:554: UserWarning: `tf.layers.max_pooling2d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.MaxPooling2D` instead.
#   warnings.warn('`tf.layers.max_pooling2d` is deprecated and '
# mur conv3d = Tensor("cnn_aggregation/conv1/Elu:0", shape=(None, 11, 50, 50, 32), dtype=float32)
# mur conv3d2 = Tensor("cnn_aggregation/conv2/Elu:0", shape=(None, 4, 17, 17, 32), dtype=float32)
# mun conv3d = Tensor("cnn_aggregation_1/conv1/Elu:0", shape=(None, 11, 50, 50, 32), dtype=float32)
# mun conv3d2 = Tensor("cnn_aggregation_1/conv2/Elu:0", shape=(None, 4, 17, 17, 32), dtype=float32)
# mrn conv2d = Tensor("cnn_aggregation_2/conv2d/Elu:0", shape=(None, 50, 50, 32), dtype=float32)
# mrn conv2d2 = Tensor("cnn_aggregation_2/conv2d2/Elu:0", shape=(None, 17, 17, 32), dtype=float32)
# 2022-08-23 17:48:05.902012: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-08-23 17:48:06.820826: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8200
# 2022-08-23 17:48:08.026920: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.90GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-23 17:48:08.084116: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.90GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-23 17:48:08.129985: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.90GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-23 17:48:08.134821: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.90GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-23 17:48:08.188446: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.90GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-23 17:48:08.188596: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.90GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-23 17:48:08.217418: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.90GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-23 17:48:08.222156: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.90GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-23 17:48:08.239177: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.90GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-23 17:48:08.241432: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.90GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-08-23 17:48:18.509621: W tensorflow/core/common_runtime/bfc_allocator.cc:457] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.81MiB (rounded to 4000000)requested by op response_attention_narrative_3_5/multihead_attention/dense/Tensordot/MatMul
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-08-23 17:48:18.509705: I tensorflow/core/common_runtime/bfc_allocator.cc:1004] BFCAllocator dump for GPU_0_bfc
# 2022-08-23 17:48:18.509733: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (256): 	Total Chunks: 134, Chunks in use: 132. 33.5KiB allocated for chunks. 33.0KiB in use in bin. 1.4KiB client-requested in use in bin.
# 2022-08-23 17:48:18.509747: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (512): 	Total Chunks: 3, Chunks in use: 1. 1.5KiB allocated for chunks. 512B in use in bin. 400B client-requested in use in bin.
# 2022-08-23 17:48:18.509763: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1024): 	Total Chunks: 41, Chunks in use: 41. 41.2KiB allocated for chunks. 41.2KiB in use in bin. 32.3KiB client-requested in use in bin.
# 2022-08-23 17:48:18.509775: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-23 17:48:18.509786: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-23 17:48:18.509800: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8192): 	Total Chunks: 2, Chunks in use: 2. 18.0KiB allocated for chunks. 18.0KiB in use in bin. 18.0KiB client-requested in use in bin.
# 2022-08-23 17:48:18.509817: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16384): 	Total Chunks: 46, Chunks in use: 45. 926.8KiB allocated for chunks. 910.0KiB in use in bin. 899.8KiB client-requested in use in bin.
# 2022-08-23 17:48:18.509832: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (32768): 	Total Chunks: 4, Chunks in use: 3. 158.0KiB allocated for chunks. 106.8KiB in use in bin. 91.5KiB client-requested in use in bin.
# 2022-08-23 17:48:18.509845: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (65536): 	Total Chunks: 2, Chunks in use: 2. 216.0KiB allocated for chunks. 216.0KiB in use in bin. 216.0KiB client-requested in use in bin.
# 2022-08-23 17:48:18.509860: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (131072): 	Total Chunks: 200, Chunks in use: 194. 31.12MiB allocated for chunks. 29.98MiB in use in bin. 29.86MiB client-requested in use in bin.
# 2022-08-23 17:48:18.509873: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (262144): 	Total Chunks: 3, Chunks in use: 3. 1.13MiB allocated for chunks. 1.13MiB in use in bin. 781.2KiB client-requested in use in bin.
# 2022-08-23 17:48:18.509887: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (524288): 	Total Chunks: 4, Chunks in use: 1. 3.26MiB allocated for chunks. 976.8KiB in use in bin. 976.6KiB client-requested in use in bin.
# 2022-08-23 17:48:18.509900: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1048576): 	Total Chunks: 6, Chunks in use: 2. 10.73MiB allocated for chunks. 3.81MiB in use in bin. 1.91MiB client-requested in use in bin.
# 2022-08-23 17:48:18.509913: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2097152): 	Total Chunks: 278, Chunks in use: 277. 1.03GiB allocated for chunks. 1.03GiB in use in bin. 1.03GiB client-requested in use in bin.
# 2022-08-23 17:48:18.509927: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4194304): 	Total Chunks: 21, Chunks in use: 21. 109.10MiB allocated for chunks. 109.10MiB in use in bin. 80.11MiB client-requested in use in bin.
# 2022-08-23 17:48:18.509942: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8388608): 	Total Chunks: 10, Chunks in use: 10. 146.39MiB allocated for chunks. 146.39MiB in use in bin. 146.39MiB client-requested in use in bin.
# 2022-08-23 17:48:18.509956: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 16.00MiB allocated for chunks. 16.00MiB in use in bin. 15.26MiB client-requested in use in bin.
# 2022-08-23 17:48:18.509967: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-23 17:48:18.509983: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-23 17:48:18.509994: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-23 17:48:18.510005: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-23 17:48:18.510017: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Bin for 3.81MiB was 2.00MiB, Chunk State:
# 2022-08-23 17:48:18.510041: I tensorflow/core/common_runtime/bfc_allocator.cc:1033]   Size: 2.15MiB | Requested Size: 976.6KiB | in_use: 0 | bin_num: 13, prev:   Size: 3.81MiB | Requested Size: 3.81MiB | in_use: 1 | bin_num: -1, next:   Size: 3.81MiB | Requested Size: 3.81MiB | in_use: 1 | bin_num: -1
# 2022-08-23 17:48:18.510051: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Next region of size 373227520
# 2022-08-23 17:48:18.510065: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5c000000 of size 4000000 next 657
# 2022-08-23 17:48:18.510074: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5c3d0900 of size 4000000 next 658
# 2022-08-23 17:48:18.510083: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5c7a1200 of size 4000000 next 659
# 2022-08-23 17:48:18.510092: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5cb71b00 of size 4000000 next 660
# 2022-08-23 17:48:18.510101: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5cf42400 of size 4000000 next 661
# 2022-08-23 17:48:18.510109: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5d312d00 of size 4000000 next 662
# 2022-08-23 17:48:18.510119: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5d6e3600 of size 16000000 next 684
# 2022-08-23 17:48:18.510128: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5e625a00 of size 4000000 next 687
# 2022-08-23 17:48:18.510137: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5e9f6300 of size 4000000 next 688
# 2022-08-23 17:48:18.510145: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5edc6c00 of size 4000000 next 685
# 2022-08-23 17:48:18.510154: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5f197500 of size 4000000 next 546
# 2022-08-23 17:48:18.510163: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec5f567e00 of size 16000000 next 672
# 2022-08-23 17:48:18.510172: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec604aa200 of size 4000000 next 686
# 2022-08-23 17:48:18.510181: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6087ab00 of size 4000000 next 689
# 2022-08-23 17:48:18.510189: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec60c4b400 of size 4000000 next 690
# 2022-08-23 17:48:18.510198: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6101bd00 of size 4000000 next 691
# 2022-08-23 17:48:18.510207: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec613ec600 of size 4000000 next 692
# 2022-08-23 17:48:18.510216: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec617bcf00 of size 4000000 next 693
# 2022-08-23 17:48:18.510225: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec61b8d800 of size 4000000 next 694
# 2022-08-23 17:48:18.510234: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec61f5e100 of size 4000000 next 695
# 2022-08-23 17:48:18.510242: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6232ea00 of size 4000000 next 696
# 2022-08-23 17:48:18.510253: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec626ff300 of size 4000000 next 697
# 2022-08-23 17:48:18.510262: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec62acfc00 of size 4000000 next 698
# 2022-08-23 17:48:18.510271: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec62ea0500 of size 16000000 next 710
# 2022-08-23 17:48:18.510280: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec63de2900 of size 4000000 next 712
# 2022-08-23 17:48:18.510289: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec641b3200 of size 16000000 next 713
# 2022-08-23 17:48:18.510298: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec650f5600 of size 4000000 next 714
# 2022-08-23 17:48:18.510306: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec654c5f00 of size 4000000 next 715
# 2022-08-23 17:48:18.510315: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec65896800 of size 4000000 next 716
# 2022-08-23 17:48:18.510324: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec65c67100 of size 4000000 next 717
# 2022-08-23 17:48:18.510333: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec66037a00 of size 4000000 next 718
# 2022-08-23 17:48:18.510341: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec66408300 of size 16000000 next 701
# 2022-08-23 17:48:18.510350: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6734a700 of size 16000000 next 725
# 2022-08-23 17:48:18.510359: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6828cb00 of size 16000000 next 727
# 2022-08-23 17:48:18.510368: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec691cef00 of size 4000000 next 704
# 2022-08-23 17:48:18.510376: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6959f800 of size 4000000 next 731
# 2022-08-23 17:48:18.510385: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec69970100 of size 4000000 next 730
# 2022-08-23 17:48:18.510394: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec69d40a00 of size 4000000 next 541
# 2022-08-23 17:48:18.510402: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6a111300 of size 4000000 next 739
# 2022-08-23 17:48:18.510411: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6a4e1c00 of size 4000000 next 740
# 2022-08-23 17:48:18.510420: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6a8b2500 of size 4000000 next 741
# 2022-08-23 17:48:18.510429: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6ac82e00 of size 4000000 next 733
# 2022-08-23 17:48:18.510437: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6b053700 of size 4000000 next 743
# 2022-08-23 17:48:18.510446: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6b424000 of size 4000000 next 744
# 2022-08-23 17:48:18.510455: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6b7f4900 of size 4000000 next 745
# 2022-08-23 17:48:18.510463: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6bbc5200 of size 4000000 next 746
# 2022-08-23 17:48:18.510472: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6bf95b00 of size 4000000 next 747
# 2022-08-23 17:48:18.510481: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6c366400 of size 16000000 next 749
# 2022-08-23 17:48:18.510490: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6d2a8800 of size 16000000 next 742
# 2022-08-23 17:48:18.510499: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6e1eac00 of size 4000000 next 732
# 2022-08-23 17:48:18.510507: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6e5bb500 of size 4000000 next 734
# 2022-08-23 17:48:18.510516: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6e98be00 of size 4000000 next 542
# 2022-08-23 17:48:18.510527: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6ed5c700 of size 4000000 next 751
# 2022-08-23 17:48:18.510535: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6f12d000 of size 4000000 next 722
# 2022-08-23 17:48:18.510544: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6f4fd900 of size 4000000 next 708
# 2022-08-23 17:48:18.510553: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6f8ce200 of size 4000000 next 762
# 2022-08-23 17:48:18.510562: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec6fc9eb00 of size 4000000 next 750
# 2022-08-23 17:48:18.510570: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec7006f400 of size 4000000 next 755
# 2022-08-23 17:48:18.510579: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec7043fd00 of size 4000000 next 756
# 2022-08-23 17:48:18.510588: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec70810600 of size 4000000 next 757
# 2022-08-23 17:48:18.510597: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec70be0f00 of size 4000000 next 758
# 2022-08-23 17:48:18.510606: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec70fb1800 of size 4000000 next 759
# 2022-08-23 17:48:18.510614: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec71382100 of size 4000000 next 760
# 2022-08-23 17:48:18.510623: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec71752a00 of size 4000000 next 761
# 2022-08-23 17:48:18.510632: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec71b23300 of size 4000000 next 707
# 2022-08-23 17:48:18.510642: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fec71ef3c00 of size 5227520 next 18446744073709551615
# 2022-08-23 17:48:18.510651: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Next region of size 536870912
# 2022-08-23 17:48:18.510660: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecde000000 of size 4000000 next 582
# 2022-08-23 17:48:18.510669: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecde3d0900 of size 4000000 next 583
# 2022-08-23 17:48:18.510678: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecde7a1200 of size 4000000 next 620
# 2022-08-23 17:48:18.510687: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecdeb71b00 of size 4000000 next 585
# 2022-08-23 17:48:18.510695: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecdef42400 of size 4000000 next 586
# 2022-08-23 17:48:18.510704: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecdf312d00 of size 4000000 next 587
# 2022-08-23 17:48:18.510713: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecdf6e3600 of size 4000000 next 588
# 2022-08-23 17:48:18.510722: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecdfab3f00 of size 4000000 next 589
# 2022-08-23 17:48:18.510732: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecdfe84800 of size 4000000 next 590
# 2022-08-23 17:48:18.510741: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece0255100 of size 4000000 next 591
# 2022-08-23 17:48:18.510750: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece0625a00 of size 4000000 next 557
# 2022-08-23 17:48:18.510758: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece09f6300 of size 4000000 next 593
# 2022-08-23 17:48:18.510767: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece0dc6c00 of size 4000000 next 592
# 2022-08-23 17:48:18.510776: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece1197500 of size 4000000 next 595
# 2022-08-23 17:48:18.510785: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece1567e00 of size 4000000 next 596
# 2022-08-23 17:48:18.510794: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece1938700 of size 4000000 next 597
# 2022-08-23 17:48:18.510803: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece1d09000 of size 4000000 next 598
# 2022-08-23 17:48:18.510811: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece20d9900 of size 4000000 next 559
# 2022-08-23 17:48:18.510820: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece24aa200 of size 4000000 next 600
# 2022-08-23 17:48:18.510829: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece287ab00 of size 4000000 next 601
# 2022-08-23 17:48:18.510837: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece2c4b400 of size 4000000 next 602
# 2022-08-23 17:48:18.510846: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece301bd00 of size 4000000 next 603
# 2022-08-23 17:48:18.510855: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece33ec600 of size 4000000 next 406
# 2022-08-23 17:48:18.510864: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece37bcf00 of size 4000000 next 527
# 2022-08-23 17:48:18.510873: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece3b8d800 of size 4000000 next 515
# 2022-08-23 17:48:18.510881: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece3f5e100 of size 4000000 next 435
# 2022-08-23 17:48:18.510890: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece432ea00 of size 4000000 next 605
# 2022-08-23 17:48:18.510899: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece46ff300 of size 4000000 next 606
# 2022-08-23 17:48:18.510907: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece4acfc00 of size 4000000 next 607
# 2022-08-23 17:48:18.510916: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece4ea0500 of size 4000000 next 608
# 2022-08-23 17:48:18.510925: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece5270e00 of size 4000000 next 609
# 2022-08-23 17:48:18.510934: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece5641700 of size 4000000 next 425
# 2022-08-23 17:48:18.510942: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece5a12000 of size 4000000 next 624
# 2022-08-23 17:48:18.510951: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece5de2900 of size 4000000 next 418
# 2022-08-23 17:48:18.510960: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece61b3200 of size 4000000 next 510
# 2022-08-23 17:48:18.510968: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece6583b00 of size 4000000 next 611
# 2022-08-23 17:48:18.510977: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece6954400 of size 4000000 next 613
# 2022-08-23 17:48:18.510986: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece6d24d00 of size 4000000 next 614
# 2022-08-23 17:48:18.510994: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece70f5600 of size 4000000 next 615
# 2022-08-23 17:48:18.511003: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece74c5f00 of size 4000000 next 616
# 2022-08-23 17:48:18.511012: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece7896800 of size 4000000 next 617
# 2022-08-23 17:48:18.511021: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece7c67100 of size 4000000 next 618
# 2022-08-23 17:48:18.511029: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece8037a00 of size 4000000 next 457
# 2022-08-23 17:48:18.511038: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece8408300 of size 4000000 next 492
# 2022-08-23 17:48:18.511047: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece87d8c00 of size 4000000 next 553
# 2022-08-23 17:48:18.511056: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece8ba9500 of size 4000000 next 622
# 2022-08-23 17:48:18.511064: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece8f79e00 of size 4000000 next 623
# 2022-08-23 17:48:18.511074: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece934a700 of size 4000000 next 460
# 2022-08-23 17:48:18.511083: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece971b000 of size 4000000 next 497
# 2022-08-23 17:48:18.511092: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece9aeb900 of size 4000000 next 462
# 2022-08-23 17:48:18.511101: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fece9ebc200 of size 4000000 next 448
# 2022-08-23 17:48:18.511110: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecea28cb00 of size 4777216 next 399
# 2022-08-23 17:48:18.511119: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecea71b000 of size 4000000 next 632
# 2022-08-23 17:48:18.511128: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7feceaaeb900 of size 4000000 next 636
# 2022-08-23 17:48:18.511136: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7feceaebc200 of size 4000000 next 408
# 2022-08-23 17:48:18.511145: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7feceb28cb00 of size 4000000 next 578
# 2022-08-23 17:48:18.511154: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7feceb65d400 of size 4000000 next 629
# 2022-08-23 17:48:18.511163: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7feceba2dd00 of size 4000000 next 638
# 2022-08-23 17:48:18.511171: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecebdfe600 of size 4000000 next 498
# 2022-08-23 17:48:18.511180: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecec1cef00 of size 4000000 next 641
# 2022-08-23 17:48:18.511189: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecec59f800 of size 4000000 next 631
# 2022-08-23 17:48:18.511198: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecec970100 of size 4000000 next 642
# 2022-08-23 17:48:18.511207: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fececd40a00 of size 5554432 next 405
# 2022-08-23 17:48:18.511216: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7feced28cb00 of size 4000000 next 496
# 2022-08-23 17:48:18.511225: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7feced65d400 of size 4000000 next 481
# 2022-08-23 17:48:18.511233: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7feceda2dd00 of size 4000000 next 465
# 2022-08-23 17:48:18.511242: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7feceddfe600 of size 4777216 next 599
# 2022-08-23 17:48:18.511251: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecee28cb00 of size 4000000 next 703
# 2022-08-23 17:48:18.511260: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecee65d400 of size 4000000 next 488
# 2022-08-23 17:48:18.511269: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7feceea2dd00 of size 4000000 next 706
# 2022-08-23 17:48:18.511277: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7feceedfe600 of size 4000000 next 711
# 2022-08-23 17:48:18.511286: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecef1cef00 of size 4777216 next 621
# 2022-08-23 17:48:18.511295: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecef65d400 of size 4000000 next 503
# 2022-08-23 17:48:18.511304: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecefa2dd00 of size 4000000 next 584
# 2022-08-23 17:48:18.511313: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecefdfe600 of size 4000000 next 472
# 2022-08-23 17:48:18.511322: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf01cef00 of size 4000000 next 394
# 2022-08-23 17:48:18.511330: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf059f800 of size 4000000 next 485
# 2022-08-23 17:48:18.511339: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf0970100 of size 4000000 next 505
# 2022-08-23 17:48:18.511348: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf0d40a00 of size 4000000 next 458
# 2022-08-23 17:48:18.511356: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf1111300 of size 4000000 next 664
# 2022-08-23 17:48:18.511365: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf14e1c00 of size 4000000 next 665
# 2022-08-23 17:48:18.511374: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf18b2500 of size 4000000 next 656
# 2022-08-23 17:48:18.511383: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf1c82e00 of size 4000000 next 453
# 2022-08-23 17:48:18.511392: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf2053700 of size 4000000 next 667
# 2022-08-23 17:48:18.511400: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf2424000 of size 4000000 next 668
# 2022-08-23 17:48:18.511409: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf27f4900 of size 4000000 next 669
# 2022-08-23 17:48:18.511418: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf2bc5200 of size 6331648 next 415
# 2022-08-23 17:48:18.511427: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf31cef00 of size 4000000 next 454
# 2022-08-23 17:48:18.511436: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf359f800 of size 16777216 next 574
# 2022-08-23 17:48:18.511445: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf459f800 of size 4000000 next 427
# 2022-08-23 17:48:18.511454: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf4970100 of size 4000000 next 410
# 2022-08-23 17:48:18.511463: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf4d40a00 of size 4000000 next 437
# 2022-08-23 17:48:18.511471: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf5111300 of size 4000000 next 612
# 2022-08-23 17:48:18.511480: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf54e1c00 of size 4000000 next 420
# 2022-08-23 17:48:18.511488: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf58b2500 of size 4000000 next 446
# 2022-08-23 17:48:18.511497: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf5c82e00 of size 4000000 next 438
# 2022-08-23 17:48:18.511506: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf6053700 of size 4000000 next 471
# 2022-08-23 17:48:18.511515: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf6424000 of size 4000000 next 416
# 2022-08-23 17:48:18.511523: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf67f4900 of size 5554432 next 627
# 2022-08-23 17:48:18.511532: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf6d40a00 of size 4000000 next 644
# 2022-08-23 17:48:18.511541: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf7111300 of size 4000000 next 630
# 2022-08-23 17:48:18.511550: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf74e1c00 of size 4000000 next 670
# 2022-08-23 17:48:18.511558: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf78b2500 of size 4000000 next 663
# 2022-08-23 17:48:18.511567: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf7c82e00 of size 4777216 next 450
# 2022-08-23 17:48:18.511576: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf8111300 of size 4000000 next 610
# 2022-08-23 17:48:18.511585: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf84e1c00 of size 4000000 next 451
# 2022-08-23 17:48:18.511593: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf88b2500 of size 4000000 next 634
# 2022-08-23 17:48:18.511602: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf8c82e00 of size 4000000 next 635
# 2022-08-23 17:48:18.511611: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf9053700 of size 4000000 next 676
# 2022-08-23 17:48:18.511620: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf9424000 of size 4000000 next 678
# 2022-08-23 17:48:18.511629: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf97f4900 of size 4000000 next 679
# 2022-08-23 17:48:18.511638: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf9bc5200 of size 4000000 next 681
# 2022-08-23 17:48:18.511647: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecf9f95b00 of size 4000000 next 677
# 2022-08-23 17:48:18.511657: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfa366400 of size 5097216 next 640
# 2022-08-23 17:48:18.511666: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfa842b00 of size 4000000 next 643
# 2022-08-23 17:48:18.511675: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfac13400 of size 4000000 next 675
# 2022-08-23 17:48:18.511683: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfafe3d00 of size 4000000 next 645
# 2022-08-23 17:48:18.511692: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfb3b4600 of size 4000000 next 646
# 2022-08-23 17:48:18.511701: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfb784f00 of size 4000000 next 647
# 2022-08-23 17:48:18.511709: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfbb55800 of size 4000000 next 648
# 2022-08-23 17:48:18.511718: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfbf26100 of size 4000000 next 649
# 2022-08-23 17:48:18.511727: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfc2f6a00 of size 4000000 next 650
# 2022-08-23 17:48:18.511735: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfc6c7300 of size 4000000 next 651
# 2022-08-23 17:48:18.511744: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfca97c00 of size 4000000 next 652
# 2022-08-23 17:48:18.511753: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfce68500 of size 4000000 next 653
# 2022-08-23 17:48:18.511762: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfd238e00 of size 4000000 next 683
# 2022-08-23 17:48:18.511770: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfd609700 of size 4000000 next 655
# 2022-08-23 17:48:18.511780: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fecfd9da000 of size 6447104 next 18446744073709551615
# 2022-08-23 17:48:18.511789: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Next region of size 268435456
# 2022-08-23 17:48:18.511797: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed80000000 of size 4000000 next 514
# 2022-08-23 17:48:18.511806: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed803d0900 of size 4000000 next 508
# 2022-08-23 17:48:18.511815: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed807a1200 of size 4000000 next 516
# 2022-08-23 17:48:18.511824: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed80b71b00 of size 4000000 next 517
# 2022-08-23 17:48:18.511833: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed80f42400 of size 4000000 next 518
# 2022-08-23 17:48:18.511841: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed81312d00 of size 4000000 next 519
# 2022-08-23 17:48:18.511850: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed816e3600 of size 4000000 next 520
# 2022-08-23 17:48:18.511859: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed81ab3f00 of size 4000000 next 521
# 2022-08-23 17:48:18.511867: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed81e84800 of size 4000000 next 522
# 2022-08-23 17:48:18.511876: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7fed82255100 of size 1000192 next 737
# 2022-08-23 17:48:18.511886: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed82349400 of size 1000192 next 738
# 2022-08-23 17:48:18.511895: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7fed8243d700 of size 1999616 next 523
# 2022-08-23 17:48:18.511903: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed82625a00 of size 4000000 next 524
# 2022-08-23 17:48:18.511912: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed829f6300 of size 4000000 next 426
# 2022-08-23 17:48:18.511921: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7fed82dc6c00 of size 2000384 next 705
# 2022-08-23 17:48:18.511930: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed82faf200 of size 1999616 next 404
# 2022-08-23 17:48:18.511939: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed83197500 of size 4000000 next 506
# 2022-08-23 17:48:18.511948: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed83567e00 of size 4000000 next 467
# 2022-08-23 17:48:18.511957: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed83938700 of size 4000000 next 502
# 2022-08-23 17:48:18.511966: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed83d09000 of size 4000000 next 530
# 2022-08-23 17:48:18.511974: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed840d9900 of size 4000000 next 531
# 2022-08-23 17:48:18.511983: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed844aa200 of size 4000000 next 525
# 2022-08-23 17:48:18.511992: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed8487ab00 of size 4000000 next 533
# 2022-08-23 17:48:18.512001: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed84c4b400 of size 4000000 next 534
# 2022-08-23 17:48:18.512009: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed8501bd00 of size 4000000 next 535
# 2022-08-23 17:48:18.512018: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed853ec600 of size 4000000 next 536
# 2022-08-23 17:48:18.512027: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed857bcf00 of size 4000000 next 537
# 2022-08-23 17:48:18.512036: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed85b8d800 of size 4000000 next 538
# 2022-08-23 17:48:18.512044: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed85f5e100 of size 4000000 next 539
# 2022-08-23 17:48:18.512053: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed8632ea00 of size 4000000 next 540
# 2022-08-23 17:48:18.512062: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed866ff300 of size 4000000 next 729
# 2022-08-23 17:48:18.512070: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed86acfc00 of size 4000000 next 728
# 2022-08-23 17:48:18.512079: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed86ea0500 of size 4000000 next 543
# 2022-08-23 17:48:18.512088: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed87270e00 of size 4000000 next 544
# 2022-08-23 17:48:18.512097: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed87641700 of size 4000000 next 480
# 2022-08-23 17:48:18.512106: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed87a12000 of size 4000000 next 619
# 2022-08-23 17:48:18.512115: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed87de2900 of size 4000000 next 547
# 2022-08-23 17:48:18.512123: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed881b3200 of size 4000000 next 548
# 2022-08-23 17:48:18.512132: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed88583b00 of size 4000000 next 549
# 2022-08-23 17:48:18.512141: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed88954400 of size 4000000 next 550
# 2022-08-23 17:48:18.512150: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed88d24d00 of size 4000000 next 551
# 2022-08-23 17:48:18.512159: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed890f5600 of size 4000000 next 552
# 2022-08-23 17:48:18.512168: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed894c5f00 of size 4000000 next 490
# 2022-08-23 17:48:18.512176: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed89896800 of size 4000000 next 554
# 2022-08-23 17:48:18.512185: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed89c67100 of size 4000000 next 555
# 2022-08-23 17:48:18.512194: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed8a037a00 of size 4000000 next 556
# 2022-08-23 17:48:18.512202: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed8a408300 of size 4000000 next 625
# 2022-08-23 17:48:18.512211: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed8a7d8c00 of size 4000000 next 529
# 2022-08-23 17:48:18.512220: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7fed8aba9500 of size 4000000 next 528
# ...
# 2022-08-23 17:48:48.684156: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 4230656 totalling 4.03MiB
# 2022-08-23 17:48:48.684164: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 4435456 totalling 4.23MiB
# 2022-08-23 17:48:48.684172: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 4457216 totalling 4.25MiB
# 2022-08-23 17:48:48.684181: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 4777216 totalling 18.22MiB
# 2022-08-23 17:48:48.684189: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 5000192 totalling 4.77MiB
# 2022-08-23 17:48:48.684197: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 5040896 totalling 4.81MiB
# 2022-08-23 17:48:48.684205: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 5097216 totalling 4.86MiB
# 2022-08-23 17:48:48.684213: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 5227520 totalling 4.99MiB
# 2022-08-23 17:48:48.684221: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 5445888 totalling 5.19MiB
# 2022-08-23 17:48:48.684229: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 5500928 totalling 5.25MiB
# 2022-08-23 17:48:48.684238: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 2 Chunks of size 5554432 totalling 10.59MiB
# 2022-08-23 17:48:48.684245: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 5751040 totalling 5.48MiB
# 2022-08-23 17:48:48.684254: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 6331648 totalling 6.04MiB
# 2022-08-23 17:48:48.684262: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 6447104 totalling 6.15MiB
# 2022-08-23 17:48:48.684276: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 6465280 totalling 6.17MiB
# 2022-08-23 17:48:48.684284: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 7001344 totalling 6.68MiB
# 2022-08-23 17:48:48.684292: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 7752448 totalling 7.39MiB
# 2022-08-23 17:48:48.684300: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 9506560 totalling 9.07MiB
# 2022-08-23 17:48:48.684309: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 9 Chunks of size 16000000 totalling 137.33MiB
# 2022-08-23 17:48:48.684317: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 16777216 totalling 16.00MiB
# 2022-08-23 17:48:48.684326: I tensorflow/core/common_runtime/bfc_allocator.cc:1072] Sum Total of in-use chunks: 1.33GiB
# 2022-08-23 17:48:48.684333: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] total_region_allocated_bytes_: 1444872192 memory_limit_: 1444872192 available bytes: 0 curr_region_allocation_bytes_: 2147483648
# 2022-08-23 17:48:48.684346: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] Stats:
# Limit:                      1444872192
# InUse:                      1431688704
# MaxInUse:                   1435802880
# NumAllocs:                        2518
# MaxAllocSize:                 62331648
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-08-23 17:48:48.684407: W tensorflow/core/common_runtime/bfc_allocator.cc:468] ****************************************************************************************************
# 2022-08-23 17:48:48.684606: W tensorflow/core/framework/op_kernel.cc:1692] OP_REQUIRES failed at transpose_op.cc:184 : Resource exhausted: OOM when allocating tensor with shape[100,1,50,200] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1374     try:
# -> 1375       return fn(*args)
#    1376     except errors.OpError as e:
#
# ~/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1358       self._extend_graph()
# -> 1359       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1360                                       target_list, run_metadata)
#
# ~/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1450                           run_metadata):
# -> 1451     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1452                                             fetch_list, target_list,
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted: OOM when allocating tensor with shape[5000,200] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node response_attention_narrative_3_5/multihead_attention/dense/Tensordot/MatMul}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[Sigmoid/_871]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) Resource exhausted: OOM when allocating tensor with shape[5000,200] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node response_attention_narrative_3_5/multihead_attention/dense/Tensordot/MatMul}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored.
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_32009/2798287037.py in <module>
#      16     bu, bn, br, bgtr, by = data_iterator
#      17     bu, bn, br, bgtr, by = sess.run([bu, bn, br, bgtr, by])
# ---> 18     candidate_scores, loss = sess.run([model.y_pred, model.loss], feed_dict={
#      19         model.utterance_ph: bu,
#      20         model.narrative_ph: bn,
#
# ~/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     965
#     966     try:
# --> 967       result = self._run(None, fetches, feed_dict, options_ptr,
#     968                          run_metadata_ptr)
#     969       if run_metadata:
#
# ~/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1188     # or if the call is a partial run that specifies feeds.
#    1189     if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1190       results = self._do_run(handle, final_targets, final_fetches,
#    1191                              feed_dict_tensor, options, run_metadata)
#    1192     else:
#
# ~/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1366
#    1367     if handle is None:
# -> 1368       return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1369                            run_metadata)
#    1370     else:
#
# ~/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1392                     '\nsession_config.graph_options.rewrite_options.'
#    1393                     'disable_meta_optimizer = True')
# -> 1394       raise type(e)(node_def, op, message)  # pylint: disable=no-value-for-parameter
#    1395
#    1396   def _extend_graph(self):
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted: OOM when allocating tensor with shape[5000,200] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node response_attention_narrative_3_5/multihead_attention/dense/Tensordot/MatMul (defined at home/kotech/workspace/ScriptWriter/modules.py:56) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[Sigmoid/_871]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) Resource exhausted: OOM when allocating tensor with shape[5000,200] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node response_attention_narrative_3_5/multihead_attention/dense/Tensordot/MatMul (defined at home/kotech/workspace/ScriptWriter/modules.py:56) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored.
#
# Original stack trace for 'response_attention_narrative_3_5/multihead_attention/dense/Tensordot/MatMul':
#   File "home/kotech/.pyenv/versions/3.8.9/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "home/kotech/.pyenv/versions/3.8.9/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "home/kotech/.pyenv/versions/3.8.9/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "home/kotech/.pyenv/versions/3.8.9/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "home/kotech/.pyenv/versions/3.8.9/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 457, in dispatch_queue
#     await self.process_one()
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 446, in process_one
#     await dispatch(*args)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 353, in dispatch_shell
#     await result
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 648, in execute_request
#     reply_content = await reply_content
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 345, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "tmp/ipykernel_32009/2798287037.py", line 10, in <module>
#     model.build()
#   File "tmp/ipykernel_32009/3570724548.py", line 127, in build
#     u_a_n, alpha_1 = multihead_attention(queries=Hu_stack[i], keys=Hn_stack[i], num_units=self.hidden_units, num_heads=self.num_heads, is_training=self.is_training, causality=False, dropout_rate=self.dropout_rate)
#   File "home/kotech/workspace/ScriptWriter/modules.py", line 56, in multihead_attention
#     Q = tf.compat.v1.layers.dense(queries, num_units, activation=tf.compat.v1.nn.relu)  # (N, T_q, C)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/core.py", line 253, in dense
#     return layer.apply(inputs)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/engine/base_layer_v1.py", line 1679, in apply
#     return self.__call__(inputs, *args, **kwargs)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/legacy_tf_layers/base.py", line 567, in __call__
#     outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/engine/base_layer_v1.py", line 765, in __call__
#     outputs = call_fn(cast_inputs, *args, **kwargs)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 692, in wrapper
#     return converted_call(f, args, kwargs, options=options)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 336, in converted_call
#     return _call_unconverted(f, args, kwargs, options, False)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 463, in _call_unconverted
#     return f(*args, **kwargs)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/keras/layers/core.py", line 1232, in call
#     outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py", line 206, in wrapper
#     return target(*args, **kwargs)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py", line 5042, in tensordot
#     ab_matmul = matmul(a_reshape, b_reshape)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py", line 206, in wrapper
#     return target(*args, **kwargs)
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py", line 3654, in matmul
#     return gen_math_ops.mat_mul(
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/ops/gen_math_ops.py", line 5712, in mat_mul
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/framework/op_def_library.py", line 748, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 3561, in _create_op_internal
#     ret = Operation(
#   File "home/kotech/venv-tensor2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 2045, in __init__
#     self._traceback = tf_stack.extract_stack_for_node(self._c_op)

# %% [markdown]
# ## variable scope 확인

# %%
#https://www.tensorflow.org/api_docs/python/tf/compat/v1/variable_scope
import tensorflow as tf
import tensorflow

tf.compat.v1.disable_eager_execution()
with tf.compat.v1.variable_scope('some_scope1'):
    with tf.compat.v1.variable_scope('sub_scope', reuse=None):
        a = tf.compat.v1.Variable(1, name='a')
        b = tf.compat.v1.Variable(2, name='b')
        c = tf.compat.v1.Variable(3, name='c')
        x = tensorflow.keras.layers.Input((5,3))
        y = tf.compat.v1.layers.dense(x, units=3)
        
with tf.compat.v1.variable_scope('some_scope1', reuse=True):
    with tf.compat.v1.variable_scope('sub_scope', reuse=None):
        # variable은 scope가 추가되며 재사용되지 않는다.
        a2 = tf.compat.v1.Variable(1, name='a')
        b2 = tf.compat.v1.Variable(2, name='b')
        c2 = tf.compat.v1.Variable(3, name='c')
        x2 = tensorflow.keras.layers.Input((5,3))
        # layer는 재사용된다.
        y2 = tf.compat.v1.layers.dense(x, units=3)

with tf.compat.v1.variable_scope('some_scope2'):
    d = tf.Variable(4, name='d')
    e = tf.Variable(5, name='e')
    f = tf.Variable(6, name='f')

h = tf.Variable(8, name='h')

for i in tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.GLOBAL_VARIABLES, scope='some_scope1'):
#for i in tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope='some_scope1'):
    #print(i)   # i.name if you want just a name
    print(i.name)   # i.name if you want just a name
print()
for v in tf.compat.v1.global_variables():
    print(v.name)
# Out:
# some_scope1/sub_scope/a:0
# some_scope1/sub_scope/b:0
# some_scope1/sub_scope/c:0
# some_scope1/sub_scope/dense/kernel:0
# some_scope1/sub_scope/dense/bias:0
# some_scope1_1/sub_scope/a:0
# some_scope1_1/sub_scope/b:0
# some_scope1_1/sub_scope/c:0
#
# some_scope1/sub_scope/a:0
# some_scope1/sub_scope/b:0
# some_scope1/sub_scope/c:0
# some_scope1/sub_scope/dense/kernel:0
# some_scope1/sub_scope/dense/bias:0
# some_scope1_1/sub_scope/a:0
# some_scope1_1/sub_scope/b:0
# some_scope1_1/sub_scope/c:0
# some_scope2/d:0
# some_scope2/e:0
# some_scope2/f:0
# h:0
# /home/kotech/venv-cpre/lib/python3.9/site-packages/keras/legacy_tf_layers/core.py:236: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /home/kotech/venv-cpre/lib/python3.9/site-packages/keras/engine/base_layer_v1.py:1676: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
